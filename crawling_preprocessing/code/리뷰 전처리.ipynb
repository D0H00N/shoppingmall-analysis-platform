# %% [markdown]
# # 📌 리뷰 데이터 전처리 및 키워드 기반 카테고리 분류
#
# ## 🔹 주요 기능
# 1. **텍스트 전처리 (Preprocessing)**
#    - 개행 문자 및 특수문자 제거
#    - 불필요한 공백 정리
#    - 맞춤법 교정 (Spell Checker)
#    - 감탄사 및 불필요한 표현 제거
#    - 한글, 영어, 숫자만 유지
#
# 2. **문장 단위 분리 및 정제 (Sentence Segmentation & Cleaning)**
#    - 리뷰를 문장 단위로 분리
#    - 각 문장을 전처리 함수로 정리하여 불필요한 요소 제거
#
# 3. **키워드 기반 카테고리 분류 (Keyword-based Categorization)**
#    - 특정 키워드(착용감, 사이즈, 내구성 등)에 따라 문장을 해당 카테고리로 분류
#    - 키워드가 없을 경우 "기타"로 분류
#
# | **카테고리**        | **설명** |
# |--------------------|----------------------------------|
# | 착용감            | 편안함, 불편함, 착용 시 느낌에 대한 언급  |
# | 사이즈            | 발볼, 발등, 크기 등 사이즈 관련 언급  |
# | 내구성 및 품질     | 내구성, 마모, 재질, 퀄리티 관련 언급  |
# | 디자인            | 스타일, 트렌드, 색상 등 디자인 관련 언급  |
# | 가성비            | 가격 대비 성능, 할인, 저렴함 관련 언급  |
# | 배송 및 포장      | 배송 속도, 포장 상태, 택배 서비스 관련 언급  |
# | 기타              | 위의 카테고리에 해당하지 않는 문장 |
#
# 4. **리뷰 데이터 가공 및 저장 (Processed Data Storage)**
#    - 리뷰 데이터를 `[review_id, text_sentence, review_category, rating]` 형태로 변환
#    - 향후 분석 및 학습을 위해 저장

# %%
# !pip install kss
# !pip install konlpy
# !pip install handspell
# Out:
# Collecting kss
#   Downloading kss-6.0.4.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting emoji==1.2.0 (from kss)
#   Downloading emoji-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pecab (from kss)
#   Downloading pecab-1.0.8.tar.gz (26.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 23.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from kss) (3.4.2)
# Collecting jamo (from kss)
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting hangul-jamo (from kss)
#   Downloading hangul_jamo-1.0.1-py3-none-any.whl.metadata (899 bytes)
# Collecting tossi (from kss)
#   Downloading tossi-0.3.1.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting distance (from kss)
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyyaml==6.0 (from kss)
#   Downloading PyYAML-6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting unidecode (from kss)
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Collecting cmudict (from kss)
#   Downloading cmudict-1.0.32-py3-none-any.whl.metadata (3.6 kB)
# Collecting koparadigm (from kss)
#   Downloading koparadigm-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting kollocate (from kss)
#   Downloading kollocate-0.0.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting bs4 (from kss)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from kss) (1.26.4)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from kss) (8.3.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from kss) (1.13.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from bs4->kss) (4.13.3)
# Requirement already satisfied: importlib-metadata>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->kss) (8.6.1)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->kss) (6.5.2)
# Collecting whoosh (from kollocate->kss)
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting xlrd==1.2.0 (from koparadigm->kss)
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from pecab->kss) (17.0.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from pecab->kss) (2024.11.6)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->kss) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pytest->kss) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->kss) (1.5.0)
# Collecting bidict (from tossi->kss)
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from tossi->kss) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=5->cmudict->kss) (3.21.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4->kss) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4->kss) (4.12.2)
# Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 8.6 MB/s eta 0:00:00
# Downloading PyYAML-6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.9/757.9 kB 36.9 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading cmudict-1.0.32-py3-none-any.whl (939 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.4/939.4 kB 41.0 MB/s eta 0:00:00
# Downloading hangul_jamo-1.0.1-py3-none-any.whl (4.4 kB)
# Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Downloading kollocate-0.0.2-py3-none-any.whl (72.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 MB 8.5 MB/s eta 0:00:00
# Downloading koparadigm-0.10.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.6 MB/s eta 0:00:00
# Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 8.4 MB/s eta 0:00:00
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 14.6 MB/s eta 0:00:00
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 26.2 MB/s eta 0:00:00
# Building wheels for collected packages: kss, distance, pecab, tossi
#   Building wheel for kss (setup.py) ... done
#   Created wheel for kss: filename=kss-6.0.4-cp311-cp311-linux_x86_64.whl size=1452480 sha256=23facc9afee5e0c8ad7b966280f332d3bd0cb9e3a2e9e02b6da5f99e9a69d5fe
#   Stored in directory: /root/.cache/pip/wheels/86/c9/5f/69b8fe9751eefbb5d087932ddf58d0f121b8e545335af7fe4e
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16256 sha256=c9a9856bfcb5c020d272b8820338a75cf6875bbb0e66e9b19bb173dd6fbaf667
#   Stored in directory: /root/.cache/pip/wheels/fb/cd/9c/3ab5d666e3bcacc58900b10959edd3816cc9557c7337986322
#   Building wheel for pecab (setup.py) ... done
#   Created wheel for pecab: filename=pecab-1.0.8-py3-none-any.whl size=26646665 sha256=0d529f3bfe4c6dd312b7e00ed30b4277e8e35c27f85a758bf4befb70d9a50046
#   Stored in directory: /root/.cache/pip/wheels/c9/0d/97/ca2bb361e44a80f4c63efe6f6438ff903fd1ab5640eedabc1b
#   Building wheel for tossi (setup.py) ... done
#   Created wheel for tossi: filename=tossi-0.3.1-py3-none-any.whl size=12130 sha256=d1897b58a1362039eea782c26048f2da8cfee6dfebb7e87528d312df1344402f
#   Stored in directory: /root/.cache/pip/wheels/36/1a/7e/0b78039c20678a6682f03cca4295efaa5fb55a3d10d7e9837a
# Successfully built kss distance pecab tossi
# Installing collected packages: whoosh, jamo, hangul-jamo, emoji, distance, xlrd, unidecode, pyyaml, kollocate, bidict, tossi, pecab, koparadigm, cmudict, bs4, kss
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
# Successfully installed bidict-0.23.1 bs4-0.0.2 cmudict-1.0.32 distance-0.1.3 emoji-1.2.0 hangul-jamo-1.0.1 jamo-0.4.1 kollocate-0.0.2 koparadigm-0.10.0 kss-6.0.4 pecab-1.0.8 pyyaml-6.0 tossi-0.3.1 unidecode-1.3.8 whoosh-2.7.4 xlrd-1.2.0
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.3.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 81.4 MB/s eta 0:00:00
# Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 33.4 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.2 konlpy-0.6.0
# ERROR: Could not find a version that satisfies the requirement handspell (from versions: none)
# ERROR: No matching distribution found for handspell

# %%
# 불용어 리스트 (set 활용으로 속도 높임)
stopwords = set([
    "완전", "진심", "정말로", "진짜루", "진짜로", "너무", "엄청나게", "진짜", "훨씬", "마치", "생각보다", "생각 보다", "상당히", '젤','되게','디게','엄청',
    "그리고", "그래서", "그러나", "하지만", "그런데", "또한", "게다가", "왜냐면", "즉", "결과적으로", "즉슨",'가장',
    "하다", "있다", "되다", "않다", "같다", "없다", "이었다", "했습니다", "했어요", "보였다", "보여요",'제일',
    "무신사", "29cm", "ABC마트", "정품", "리뷰", "구매평", "상품평", "사이트", "링크", "네이버", "카카오", "페이스북",
    "진짜", "정말", "생각", "그냥", "솔직히", "어느 정도", "조금", "조금은", "대충", "뭔가", "이것", "저것", "이건", "저건", "너무", "엄청", "매우",
    '약간','약간의','좀','그래도','뭔가','먼가','꼭','다만','딱','넘','너무','아주','와우','오우','일단','근데','살짝','점점'
])

# 토픽 분류를 위한 키워드 모음
extended_keyword_dict = {
    "착용감": [
        "착용", "편안", "불편", "쿠션", "푹신",'폭신', "딱", "아픔",'아픕', "아파","아프",'아플','아픈', "편함", "편해",'편하', "착화", "장시간",'양말 필수','양말은 필수',
         "가볍", "가벼", "무겁","무거", "통풍", "신축", "탄력", "착 감" , '까져','까지', '반창고','밴드','편한','피로','물집','상처','좁아','좁고','좁네','타이트','데일리',
        '포근','느낌','부드','벗겨','따뜻','따듯','길들','길드','까져','까졌','까졋','까진','까지','저려','무리', '착 화','양말','끼는','낍','까지','까졌','까집','라이트'
    ],
    "사이즈": [
        "사이즈", "사 이즈",'사이주', "크","큽", "작", "발 볼", "길이", "정사이즈", "오버", "딱맞다","발볼",'꽉','큰','벗겨','여유','널널','치수','10단위','10 단위','5단위',
        '5 단위',"헐렁", "슬림", "루즈", '210','215','220','225','230','235','240','245','250','255','260','265','270','275','280','285','290','295','300','업','벗겨',
        '여유','발등','끼'
    ],
    "내구성 및 품질": [
        "내구성", "오래", "튼", "질", "마감", "재질", "해짐", "금방", "벗겨짐", "찢어","퀄리티", "박음","본드","냄새",'닳',
        "스크래치", "먼지", "단단", "마모", "시간지남", "늘어", "터짐", "탄탄",'가죽'
    ],
    "디자인": [
        "디자인", "스타일",'예쁨','이쁨',"예쁜",'이쁜',"예뻐",'이뻐',"예쁘",'이쁘','이뻤','예뻤', "멋짐", "심플", "트렌디", "고급", "유행", "감각", "클래식", "어울", "모양","룩",
        "세련", "귀여운", "차분한", "화려함", "깔끔한", "베이직", "유니크", "섹시", "모던", "주얼", '블랙', '화이트', '흰', '검', '색' ,'핏','쉐입','쉐잎','아이보리',
        '코디','외관','미니','색감','튀','컬러','착장','귀엽','귀여','남성','여성','룩','크기','옷','실물','굽','높이','패션','팬츠','다리','바지','길어',
        '앞','뒤','뒷','이쁩','예쁩','광택','멋','포인트','깔끔','아무 옷','아무옷','어떤 옷','어떤옷','무광','유광','정장'
    ],
    "가성비": [
        "가성비","가성 비", "가격대비", "비싼","비싸", "저렴", "할인", "가격", "돈", "합리적", "질 대비", '블프','세일','입문',
        "싼", "싸게", "싸네", "비싼", "가격만족", "가격적당", "가격부담", "경제적", "가격높음", "퀄리티대비", "가격메리트", "아깝다", "아까운",'득템'
    ],
    "배송 및 포장 및 응대": [
        "배송", "빠름", "느림", "포장", "박스", "찢어짐", "배송", "파손", "안전포장", "택배", '도착','출발','과정',
        "지연", "빠른배송", "포장", "배송빠름", "배송만족", "택배기사", "빠른도착", "파손됨",'불량','응대','친절'
    ]
}

# %%
# 함수 모음

import kss
import re
from hanspell import spell_checker
import pandas as pd

def correct_spelling(text):
    try : return spell_checker.check(text).checked
    except : return text  # 오류 발생 시 원본으로

def preprocess_text(text):
    text = text.replace("\n", " ")  # 개행 문자 제거
    text = re.sub(r"\.{2,}더보기", "", text)
    return correct_spelling(text)  # 맞춤법 교정 추가

def normalize_spaces(text):
    return ' '.join(text.split())

def clean_text_no_morph(text):
    text = re.sub(r"[ㅋㅎㅠㅜㄷ]+", "", text)     # 감탄사 및 불필요한 표현 제거
    words = text.split()  # 띄어쓰기 기준으로 나눔
    words = [word for word in words if word not in stopwords]  # 불용어 제거
    cleaned_text = normalize_spaces(" ".join(words)) # 띄워쓰기 정규화
    cleaned_text = re.sub(r"[^가-힣a-zA-Z0-9\s]", "", cleaned_text) # 숫자, 한글, 영어만 유지 (특수문자 제거)

    return cleaned_text

def process_review_no_morph(review):

    review = preprocess_text(review)  # 불필요한 요소 제거
    sentences = kss.split_sentences(review)  # 문장 분리
    sentences = [clean_text_no_morph(sentence) for sentence in sentences]  # 각 문장에서 정리
    return sentences  # 리스트 형태로 반환

def assign_labels(sentence):
    #각 문장별로 카테고리 분류
    labels = []
    for category, keywords in extended_keyword_dict.items():
        if any(keyword in sentence for keyword in keywords):  # 키워드 포함 여부 확인
            labels.append(category)
    return labels if labels else ["기타"]  # 키워드가 없으면 '기타' 카테고리로 분류

def process_reviews_with_labels(reviews):
    results = []

    for review_id, review_text, rating in reviews:  # CSV에서 불러온 데이터를 처리
        processed_sentences = process_review_no_morph(review_text)  # 전처리 수행

        for sentence in processed_sentences:
            labels = assign_labels(sentence)  # 키워드 매칭 수행
            results.append([review_id, sentence, labels,rating])  # [리뷰ID, 전처리된 문장, 키워드 영역]로 반환

    return results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-1d8434dbf10a> in <cell line: 0>()
#       3 import kss
#       4 import re
# ----> 5 from hanspell import spell_checker
#       6 import pandas as pd
#       7
#
# ModuleNotFoundError: No module named 'hanspell'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # 테스트

# %%
# 실제 활용해보기, 데이터 로드

'''import pymysql

conn = pymysql.connect(
    host="15.152.242.221",
    user="admin",  # 사용자의 MySQL 계정
    password= "Admin@1234",  # MySQL 비밀번호
    database="musinsa_pd_rv",
    charset="utf8mb4"
)

# SQL 쿼리 실행 (rating과 review_text 가져오기)
query = "SELECT rating, review_text FROM reviews WHERE review_text IS NOT NULL AND review_text != ''"
df = pd.read_sql(query, conn)
conn.close() '''

#df = pd.read_csv("G:\내 드라이브\자료\멀티캠퍼스\최종 프로젝트\Reviews.csv")
df = df[1500:2000] #일단 테스트로 500개의 데이터로만 진행, 만약 기능이 완성된다면 전체 데이터로 진행
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 3000 to 3499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_id    500 non-null    object
#  1   product_id   500 non-null    int64
#  2   rating       500 non-null    int64
#  3   review_text  500 non-null    object
#  4   review_date  500 non-null    object
#  5   review_size  500 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
#  review_id, review_text,rating 컬럼만 가져오기
review_data = df[['review_id', 'review_text','rating']].values.tolist()
review_data #확인
# Out:
# [['60041401', '슬랙스 바지 등에 신기에 무난합니다\n발이 아직 길이 안들어서 그런가 오래신지는 못하겠네요', 5],
#  ['60022817', '너무 이뻐서 재주문하고자 합니다 이쁜제품 감사드려요!', 5],
#  ['59758881', '살짝 크긴한데 입을만해요\n색상 마음에 들고 만족합니다', 5],
#  ['59671660', '첫 입문 더비인데 완전 편하고 가격대비 완전 훌륭한 것 같아요! 자주 신을 것 같아요😊', 5],
#  ['59614714', '사이즈 잘 맞고 어느정도 키높이효과 잇어요. 좋아요', 5],
#  ['59389900', '아주조아요 품질도 좋습니다. 깔끔하구용 고마워요', 5],
#  ['59327205', '잘사용하고있어요 감사합니다 ㅎㅎ 제품이 사진과 같아요', 5],
#  ['58969743', '정 사이즈로 주문하시면 됩니다.\n\n기본적으로 정장 구두라기 보다는 캐주얼 하지만...더보기', 5],
#  ['59020127', '저렴하게 좋은 제품 구매 했어요!\n비슷한 가격대에서 최고예요!! 많이 파세요!!', 5],
#  ['58984930', '좋아요 색감도 예쁘고 여기저기 매치하기 좋네요.', 5],
#  ['58969911', '정 사이즈로 가시면 되고, 캐주얼 하면서\n\n편안한 남성 구두를 찾는다면 대안이 없을 정도로...더보기', 5],
#  ['58969814',
#   '무신사에서 구매하고 가장 만족하는 제품 중에 하나\n\n기본적으로 편안하면서 캐주얼 하게 입고 싶을 때...더보기',
#   5],
#  ['58926643', '지금까지 신었던 구두중에 발도 제일 편하고 가성비도 훌류해요', 5],
#  ['58926626', '지금까지 신었던 구두중에 발도 제일 편하고 가성비도 훌륭해요', 5],
#  ['58922693', '보기보다 너무 가볍고 편해요. 아무 옷에나 다 잘 어울리는 기본템입니다.', 5],
#  ['58922465',
#   '사이즈는 넉넉한 편이고, 굽이 좀 있는 편인데 반해 너무 가볍고 편합니다. 치노, 셋업, 데님 아무데나 다 잘\n어울려요ㅋ',
#   5],
#  ['58677455', '생각보다 괜찮아요! 가성비 좋은 상품이네용\n사이즈는 정사이즈로 하니 딱 맞네요', 5],
#  ['58585939', '이거 물건이네요\n뒤꿈치 까질일없고\n바닥면 푹신하고...더보기', 5],
#  ['58555679', '사이즈 정사이즈이고 편안하네요.\n딱딱하지않고 신을만합니다.', 5],
#  ['58547949', '저렴한 가격에 가성비 좋은 구두입니다. 만족해요.', 5],
#  ['58486300', '발볼 때문에 275에서 280 신는 사람인데 이건 270 정사이즈도 발볼이 적당하고 편해서 좋아요!', 5],
#  ['58461470', '앞쪽 갈라짐 상태에 따라 달라지는듯\n가격대비 괞찮아요', 4],
#  ['58146908',
#   '그냥 쉽게 쉽게 신기 편하고, 가성비 구두 같은 느낌입니다. 더비슈즈나 구두 입문할까 고민될 때 구매해서\n신어보시면 높은 확률로 만족하실 거에요!',
#   5],
#  ['57990919',
#   '다른분들 리뷰보고 샀는데 착화감 진짜 좋습니다\n약간 굽이높아 자연스런 키높이효과도 있고, 디자인이 무난해서 출근룩에도 자연스러워요.첫 더비슈즈였는데\n대만족입니다',
#   5],
#  ['57990928',
#   '다른분들 리뷰보고 샀는데 착화감 진짜 좋습니다\n약간 굽이높아 자연스런 키높이효과도 있고, 디자인이 무난해서 출근룩에도 자연스러워요.첫 더비슈즈였는데\n대만족입니다',
#   5],
#  ['57990898',
#   '다른분들 리뷰보고 샀는데 착화감 진짜 좋습니다\n약간 굽이높아 자연스런 키높이효과도 있고, 디자인이 무난해서 출근룩에도 자연스러워요.첫 더비슈즈였는데\n대만족입니다',
#   5],
#  ['57914368', '신발 편하고 좋네요.\n사이즈도 디자인도 맘에들어요', 5],
#  ['57896928',
#   '깔창있는 상태에서 끈있는 코부분이 너무 타이트하게 제작되어있어 사이즈가 맞음에도 신발신기가\n불가능할정도로 힘들었습니다.\n결국 깔창을 빼고 신었는데 원래 이렇게 제작이 되는건지 아니면 제가 불량상품에 걸린건지 좀 아쉬웠습니다.',
#   2],
#  ['57783017', '290 엄청 크긴 하네요.\n발 큰 사람들에겐 제격입니다.', 5],
#  ['57751214', '마무리 깔끔하고 보통 245 250 신는데 잘 맞습니다. 통바지에 잘 어울리겠어요.', 5],
#  ['57751187', '발이 작은편인데 나름 크게 보이고 굽도있어 키높이효과도 있어요. 마무리 깔끔하고 흠잡을데 없네요.', 5],
#  ['57728768', '가성비좋고 무난하게 편안해요 가볍고 경조사에 신고가기 좋아요', 5],
#  ['57727367', '더비슈즈 처음 사봤는데 생각보다 발도 편하고 코디하기 좋네요', 5],
#  ['57653420', '가성비로 출근할 때 신기 딱 좋은 구두입니다. 생각보다 편하고 좋습니다.', 5],
#  ['57489509', '더비슈즈 너무 이뻐요 로퍼랑 같이 번갈아가면서 신는데 너무 편해요', 5],
#  ['57453186', '생각했던것보다 안크고 딱맞아요 그리고 엄청 편해요', 5],
#  ['57264666', '구두는 처음신어보는데 생각보다 가볍고 편해서 좋네요!', 5],
#  ['57217522', '사이즈 적당히 잘 맞고 원하던 아이템입니다 마음에 들어요!', 5],
#  ['57206842', '무난해서 아무데나 신기 편합니다 사이즈도 정사이즈 입니다', 5],
#  ['57197500', '만족합니다 ㅎㅎ 너무좋아요\n저렴하게 잘 구매했어요', 5],
#  ['57177328', '편하고 이뻐요 운동화 280인데 정사이즈 주문했어요', 5],
#  ['57126645',
#   '구두를 신고 벗을 때 운동화 신고 벗듯이 편안한 게 가장 큰 장점이구요 걷거나 뛸때도 발 아픈 곳 없이 저의 발에\n착 잘 맞습니다. 다음에 구두 살 때도 첫번 째로 이곳을 확인할 것 같아요!',
#   5],
#  ['57126507',
#   '일터에서 신을 편한 구두를 찾다 할인해서 구매해 봤습니다.\n오자마자 처음 신었을 때 발이 아프지 않고 편하기 쉽지 않은데 이 구두는 편안했어요! 그후로 쭉 잘 신고 있구요\n자주 사용해서 주름이 졌지만 자연스러운 주름이라 신경쓰이진 않구요 너무너무 편해서 구두하나 더 필...더보기',
#   5],
#  ['57124704', '딱 기본템인 것 같아요. 디자인도 깔끔해서 좋네요.', 5],
#  ['57120911', '아주 예뻐요 재구매입니다. 추천합니다^^\n\n평소 265 신어요', 5],
#  ['57118582',
#   '디자인이 무난해요 발볼이 살짝끼지만 그래도 착용했을때 가볍고 너무 편한거같아요 가격대비 너무 만족합니다 ^^',
#   5],
#  ['57048701', '더비슈즈 처음사봤는데 이쁘고 발도 생각보다 편하네요', 5],
#  ['57001356', '다 좋은데 발등이 들어갈때 아파요~약간 업해도 될거같아요^^', 5],
#  ['56996566',
#   '딱 가격대 맞는 퀄입니다 입문이나 부담 없이 신기에 적합한거 같아요\n끈이나 디테일이 아쉽게도 고급스럽지는 않아요\n발목 많이까집니다 패드나 꽉 맞는 사이즈 사시는걸 추천 드려요',
#   3],
#  ['56972619', '만족합니다 합리적인가격에 사서 만족합니다 좋은상품 앞으로도 부탁해요', 5],
#  ['56912183', '나가서 신어보진않았지만\n발사이즈 딱맞고 예쁘네요', 5],
#  ['56603472', '오랫동안 장바구니에만 넣어놨다가\n이제서야 구매를 하네요\n처음이라 잘 안들어가고 딱딱하지만...더보기', 5],
#  ['56603464', '오랫동안 장바구니에만 넣어놨다가\n이제서야 구매를 하네요\n처음이라 잘 안들어가고 딱딱하지만...더보기', 5],
#  ['56603452', '오랫동안 장바구니에만 넣어놨다가\n이제서야 구매를 하네요\n처음이라 잘 안들어가고 딱딱하지만...더보기', 5],
#  ['56486112', '처음으로 더비슈즈 입문하는데\n정말 편하네요\n재고때문에 배송이 느렷던거 빼고는...더보기', 5],
#  ['56469716', '발볼 넓은편인데 딱 맞고 착화감이 아주 편하네여', 5],
#  ['56468767', '발볼 넓은편인데 딱 맞고 착화감이 아주 편하네여', 5],
#  ['56464125', '만족할 만큼 좋은 상품이에요\n감사합니다^^ 다른 신발도 사볼게요', 5],
#  ['56464107', '만족할 만큼 좋은 상품이에요\n감사합니다^^ 다른 신발도 사볼게요', 5],
#  ['56456810', '마이에미프로젝트 역시 편합니다\n이가격대에 이런 신발 없숩니다', 5],
#  ['56451630', '다른 리뷰처럼 끈은 좀 아쉽지만\n가죽재질이나 착화감은 아주 훌륭합니다\n전투용으로도 아주 만족합니다', 5],
#  ['56450888', '꽤나 가성비 좋고 싸게 신을 수 있는 가죽 로퍼에요.', 5],
#  ['56427387',
#   '아니 진짜 이 사람들 신발 정말 잘 만드네요!\n어떤 꾼들이 만들지 모르겠지만… 진짜 대단해요!...더보기',
#   5],
#  ['56415460', '평소 운동화 275신는데 270사이즈 잘 맞습니다. 가볍고 좋아요.', 5],
#  ['56408654', '신발이 가볍고 키높이가 마니들어가있는데도 신었을때 편해요\n잘 만든듯', 5],
#  ['56408554', '무난한 디자인이고 착화감이 좋아서 자주 신을듯.\n소가죽이라 오래 신겠죠?', 5],
#  ['56408404', '무엇보다 소가죽인데도 신었을때 너무 편했어요', 5],
#  ['56338366', '사이즈가 좀 크네요. 편하기는 엄청 편합니다. 한사이즈 다운해서 신으면 될꺼 같아요.', 4],
#  ['56298457', '편하고 좋아요 가성비도 좋고 색감도 만족스러워요', 5],
#  ['56238215', '저렴하레 잘샀네요. 정사이즈로 착화감도 괜찮습니다.', 5],
#  ['56216576', '디자인이 이쁘고 가격이 너무 착해서 좋은거 같어요 ㅎ', 5],
#  ['56205666',
#   '와...구두 신고 일하는 사람인데 스타일도 챙겨야 해서 늘 불편해도 예쁜 구두를 신었는데요. 후기 믿고 사봤는데\n예쁘기도 하고 지금까지 살면서 신은 구두 중 가장 편하네요. 근데 저렴하기까지! 그래서 두고두고 신으려고 하나\n있는데 또 하나 더 샀습니다.',
#   5],
#  ['56170403', '제가 발볼이 넓은편인데 정사이즈 주문했어요 착용감도 편하고 디자인도 맘에 듭니다 이쁘네요', 5],
#  ['55962429',
#   '여자가 신어도 이쁩니다. 레드컬러 양말에 전체적으로 검정색 코디하니까 세련되보이고 굽이 있지만 착화감도\n편합니다.',
#   5],
#  ['56117817',
#   '사이즈 때문에 고민하다가 280 주문했는데 편하네요. 굽이 높은데 딱딱하지 않아서 오래 걸어도 편안핮니다.',
#   5],
#  ['56078289', '남자친구 선물 주려고 구매했는데 너무 너무 만족하더리구요!!', 5],
#  ['56078273', '남자친구 선물 주려고 구매했는데 너무 너무 만족하더리구요!!', 5],
#  ['56068689', '무광에 기본적인 디자인이라 어디든 잘 어울릴 듯.\n저렴한 가격에 득템했네요.', 5],
#  ['56068543', '가죽이 얇지만 부드럽고 촉감이 좋습니다.\n바닥도 쿠션이 좋아 편합니다.', 5],
#  ['56055393',
#   '엄청난 세일로 구매했습니다. 발볼이 안 맞을까 평소 구두 사이즈가 아닌 운동화 사이즈로 구입했더니 잘 맞네요.\n발볼이 좁은게 아니면 운동화 정사이즈 추천입니다.\n가죽은 얇은 편이나 밑창이 쿠션감이 좋습니다.',
#   5],
#  ['56052305', '기본템으로 무난하게 신기 좋아요!\n가격대비 좋습니당', 5],
#  ['56050286', '다른제품도 구매하려고합니다. 좋은제품 감사합니다', 5],
#  ['56035239', '가격이 합리적이고 사이즈가 살짝 크니 참고하시면 좋을 것 같습니다', 5],
#  ['56031259', '자주 신지는 않을거라 싼거 샀는데 괜찮네요 사이즈도 운동화 신는 사이즈랑 똑같이 샀어요', 5],
#  ['55965209', '신발 이뻐요 편하고\n근데 좀 크게 나온듯 실제로도 커보임!', 4],
#  ['55961008', '발볼이 넓은 편인데 불편하지 않아요\n다른 구두에 비해서 무게가 상당히 가벼워서 피로도가 줄었습니다', 5],
#  ['55960994', '발볼이 넓은 편인데 불편하지 않아요\n다른 구두에 비해서 무게가 상당히 가벼워서 피로도가 줄었습니다', 5],
#  ['55959595', '세일해서 사봤는데 단정하고 깔끔해서 이쁩니다!\n잘 산것 같아요ㅎㅎ', 5],
#  ['55950789', '배송도 빠른 편이고 가격대비 퀄리티도 좋습니다', 5],
#  ['55904141', '너무좋습니다 또살 의향있어요\n핏도 너무 좋습니다 ㅎㅎ', 5],
#  ['55864438', '신발은 이쁘고 착화감도 편합니다\n다만 발이 좀 커보이는 신발이예요', 4],
#  ['55819695', '면접볼 때 신으려고 샀는데 생각보다 편하고 좋아요', 5],
#  ['55815409',
#   '사이즈가 살짝 크긴 하지만 디자인이랑 착화감은 대만족입니다!!! 이런 신발을 이제 발견해서 다음에는 로퍼\n도전해야겠습니다 ㅎㅎ',
#   5],
#  ['55766671',
#   '마감이 세상 허술하나 멀리서 보기엔 괜찮음. 가격대에 맞는 퀄리티로 전투용에 적합. 하루정도 신으면 모양이 좀\n잡힘',
#   3],
#  ['55766534',
#   '처음 왔을때는 세상 이상한 모양이었는데 하루정도 신고다니면 라인이 잡힘. 제품 마감이 매우 아쉬움. 자세히\n안보면 전투용으로 괜찮음.',
#   3],
#  ['55738901', '265 였음 딱 편하게 잘맞았을텐데 저에겐 아주 살짝 작지만 얇은 면양말 신으면 나름 잘 신을수 있어요.', 5],
#  ['55738097', '아주 좋습니다 굿굿 배송이 빠르고 상품이 마음에들어요', 5],
#  ['55737662', '아주 좋습니다 굿굿 배송이 빠르고 상품이 마음에들어요', 5],
#  ['55737649', '아주 좋습니다 굿굿 배송이 빠르고 상품이 마음에들어요', 5],
#  ['55707913', '배송 빠르게 잘 왔습니다.\n가성비 좋은 제품인거 같아요', 5],
#  ['55682174', '요번 친척형 결혼식겸 평소에 신고다닐려고 입문용으로 샀습니다 발285~290인데도 딱맞아요', 5],
#  ['55675567', '상당히 아주 많이 마음에 들어요 ㅎㅎ\n좋은 제품 감사합니다', 5],
#  ['55671598',
#   '보통 운동화 265신다보니 260 시켰는데 살짝 끼더라고요. 근데 깔창이 높아서 그렇지 일반깔창 하면 개꿀이요',
#   5],
#  ['55668314', '가격 저렴하게 잘산거같아요\n착화감은 제대로 신어봐야 알거같아요', 5],
#  ['55668283', '가격 저렴하게 잘산거같아요\n착화감은 제대로 신어봐야 알거같아요', 5],
#  ['55638632', '첫 더비슈즈 엄청만족합니다 가격도 싸고 입문용 괜찮은거같아요', 5],
#  ['55617628', '평소에 신던 구두와 다르게 발바닥 쿠션이 상당해서 발에 피로가 많이 줄어들 것 같습니다.', 5],
#  ['55617609', '평소에 신던 구두와 다르게 발바닥 쿠션이 상당해서 발에 피로가 많이 줄어들 것 같습니다.', 5],
#  ['55606299', '스타일링하기 무난하고 가죽질감도 좋고 신기 편해요~', 5],
#  ['55606285', '스타일링하기 무난하고 가죽질감도 좋고 신기 편해요~', 5],
#  ['55603610',
#   '발볼이넒어서 285~290신는데 잘맞고 뒤꿈치 살짝뜨는데 꽉끈하먼 괜찮아집니다 오른쪽 발볼 살짝\n끼는거같은디 신다보면 늘어나니 계속신을려규요',
#   5],
#  ['55580212', '좋아요 원하던 디자인이라 마음에 들고 사이즈도 잘 맞아요', 5],
#  ['55560240', '완전무광도 아니고 은은하니 예뻐요 싼만큼 가죽이 좀 얇은 감은 있어요', 5],
#  ['55560135', '가성비 미쳤네요 이가격에 이런 품질은 놀랍네요', 5],
#  ['55525182',
#   '이게 구둔지 단화지 모를만큼 일단 편안합니다. 닥터마틴류는 처음에 길들이는데 엄청 고생하는데 그런게 1도\n없습니다. 바로 달리기 각. 바닥이 높아서 키높이 효과도 상당한것도 장점입니다.\n단, 깔창 바닥부에 노란색 로고가 있는데.. 그게 앉을때나 다리꼬을깨 발을 들면 발바닥에 보이는게 매우...더보기',
#   3],
#  ['55524916', '배송빠르고 좋았어요 재질도 쫀쫀하니 다음에또구매할생각있습니다', 5],
#  ['55523428', '가격대비 가성비 좋은 신발인굿 같습다 잘 입을게요', 3],
#  ['55492565',
#   '몇년만에 신발 밑창이 뜯어지고 뒷꿈치가 헤져서 새로 구입합니다!!\n일하는데 발이 편해서 자주 신어요\n다음에 또 구매할게요',
#   5],
#  ['55490250', '입문하기도 좋고 디자인도 괜찮고 전투용으로 추천합니다.', 5],
#  ['55471429', '싼맛으로 신는즁 가송비 좋음 싼티 않나진 않음 좋음', 5],
#  ['55439802', '일단 가성비제품이라 걸을때 좀 불편하고 뒤꿈치 피나기 쉬움', 3],
#  ['55391069', '초반에 신으면 발이 조금 아프고 불편하기는 한데, 적응되면 편하게 느껴집니다. 디자인도 예쁘고 좋습니다', 5],
#  ['55386929', '가성비 굉장히 좋아요 볼이 살짝 작긴한데 디자인 가죽 아웃솔 다 가격대비 대만족입니다.', 5],
#  ['55386919', '가성비 굉장히 좋아요 볼이 살짝 작긴한데 디자인 가죽 아웃솔 다 가격대비 대만족입니다.', 5],
#  ['55334139', '배송 정말 빠르구여. 아쉬운 건 배송 왔을 때 신발 표면에 껍질이 있어 싼마이 느낌이 쫌 났네여', 5],
#  ['55334130', '배송 정말 빠르구여. 아쉬운 건 배송 왔을 때 신발 표면에 껍질이 있어 싼마이 느낌이 쫌 났네여', 5],
#  ['55324625', '배송이 빠르고 키높이가 높아서 너무 만족스럽습니다.', 5],
#  ['55322712', '할인해서 좋은 가격에 구매했습니다 가격대비 만족합니다', 5],
#  ['55322697', '할인해서 좋은 가격에 구매했습니다 가격대비 만족합니다', 5],
#  ['55154580',
#   '발 실측 260mm라 운동화 270 신는데 운동화 시이즈로 사면 된다고 해서 270 샀는데 사이즈 딱 맞네요.',
#   5],
#  ['55097657', '가성비가 좋고 가볍고 편안해요 키높이도 조금 잇는거 같고 좋네요', 5],
#  ['55016046', '소개팅때 신고 나가려고 샀는데 괜찮았음 성공적이었음', 5],
#  ['54896946', '가격대비 질이 좋고 예쁩니다\n열심히 신고 다니다가 망가지면 또 살거에요', 5],
#  ['54895659', '이 브랜드의 신발이 편해서 몇번사서쓰고있는데 이거는 조금 불편해요', 3],
#  ['54537414', '금액 대비 디자인은 정말 예쁘고 착화감도 하루 이틀 신으면 편합니다 데일리로 신기 좋아요', 5],
#  ['54526329', '265 였음 딱 편하게 잘맞았을텐데 저에겐 아주 살짝 작지만 얇은 면양말 신으면 나름 잘 신을수 있어요', 5],
#  ['54509037', '필요해서 구매했습니다 맘에들어요 감사합니다', 5],
#  ['54422903', '입문용으로 하나 구매했습니다\n그냥 무난하게 신을 수 있을 것 같아요', 5],
#  ['54167005', '사이즈도 적당하고 신었을때 착용감도 좋습니다~', 5],
#  ['54135316', '광이 좀 있는 편이구요, 정사이즈 선택하셔도 좋을듯 합니다. 무난하게 신기 좋을듯 하네요', 5],
#  ['54125351',
#   '가성비가 진심 미쳤어요\n더비 슈즈는 다 불편하다고 생각했는데 이건 처음부터 신고 다닐만 해서 좋았습니다\n제 사이즈는 250은 너무 꽉 맞고 260은 살짝 남는 정도입니다',
#   5],
#  ['54113296', '데일리로 신기에 너무 예뻐용 자주 신을 것 같습니다', 5],
#  ['54113284', '착용감도 좋고 편하게 신을 수 있을 것 같아요 아주 예쁩니당', 5],
#  ['54113273', '생각보다 발이 편해서 좋았어요 데일리로 신기에도 좋네요', 5],
#  ['54109361', '생각보다 얄쌍해서 덜 캐주얼한 느낌이 있지만 기본 더비로서는 굿입니다.', 5],
#  ['54109352', '생각보다 얄쌍해서 덜 캐주얼한 느낌이 있지만 기본 더비로서는 굿입니다.', 5],
#  ['54088788', '사이즈 정사이즈이고 이쁩니다. 새신발임에도 뒷꿈치가 까지서나 하는 불편한거 없이 잘 신고 있습니다.', 5],
#  ['53934088',
#   '가격때문에 기대 안 하고 샀는데 가격대비 잘 나온 상품인거 같아요. 몇 번 신을 생각으로 샀는데 많이 신을꺼\n같아요.',
#   4],
#  ['53925165',
#   '광이 조금 있는 편이고 굽이 어느 정도 높은 제품이라 키높이 구두로도 손색이 없습니다 ㅎㅎ 가성비 더비 슈즈를\n찾고 계시면 추천드립니다 ㅎㅎ',
#   5],
#  ['53925131',
#   '가성비 더비 슈즈를 찾고 계신다면 추천드립니다 ㅎㅎ 가격대비 색감 및 착용감이 너무 좋아서 다른 색상도 사고\n싶은 마음이예요 ㅎㅎ',
#   5],
#  ['53699059',
#   '그냥 완전 최고에요 유명하고 스태디샐러인 제품도 나름 비싸게 주고사서 신어봤지만 엄청 무겁고 발아작나고\n도대체 왜유명한거지 왜 좋고 스태디샐러인거지? 했었는데 여기 제품 두번째인데 가격대비 싼티도 안나고\n데일리로 신기 완전좋고 새상품 정사이즈로 신어도 진짜 발 하나도 안아프고 완전편하고 좋아요. 두제품...더보기',
#   5],
#  ['53681526', '가격 적당해서 무난하게 막 신기 좋아요! 발 편해요', 5],
#  ['53681504', '가격 적당해서 무난하게 막 신기 좋아요! 발 편해요', 5],
#  ['53665440', '배송 빠르고 신발이 막 편하지는 않은데 무난하게 신기에 좋아요', 5],
#  ['53561791', '배송도 배르고 시계도 너무 마음에 드네요 오랫동안 이쁘그게 착용하겠습니다\n다 갑사합니다', 5],
#  ['53490475', '너무 예쁘고 발에 잘 맞아서 편합니다 잘 사용하겠습니다!', 5],
#  ['53351548', '착화감이 너무 편해서 계속 찾게되는 신발 회사에 계속 이것만 신고가게돼요', 5],
#  ['53348085',
#   '평발이라 착화감에 매우 예민한데 이 신발은 매우 푹신해서 전혀 부담없어요! 오히려 더 신고다니고 싶더라구요.\n신발 디자인도 제일 무난해서 저처럼 패션모르는 사람은 이 신발을 우선으로 넓혀가는게 좋을거 같습니다.',
#   5],
#  ['53317137', '가죽 재질도 괜찮고 발볼이 넓은 사란한테도 잘 맞음', 4],
#  ['53311302', '👌👌😘입문용으로 완전 강추 그립니다 발 완전 편해요!! 강추', 5],
#  ['53231544', '컴포트하고 디자인도 예쁘네요. 편하게 여기저기신기 좋은거같아요.', 5],
#  ['53185648', '착화감이 가죽 구두임에도 불구하고 편했어요! 키높이도 적당히 되고 좋아요:)', 5],
#  ['53033092', '굽도 높고 운동화처럼 편해요\n휘뚜루마뚜루 신기 좋은것같습니다', 5],
#  ['52941902', '할인과 쿠폰으로 싼 가격에 잘 샀습니다. 이 가격에 이 퀄리티면 나중에 또 구매할거 같아요!', 5],
#  ['52834286',
#   '고민하고 주문을 했는데 사진처럼 괜찮네요\n가죽이라하지만 레자같아 보입니다\n하지만 저렴하니깐 그만큼 신을수 있을거 같아요...더보기',
#   5],
#  ['52502630',
#   '발볼 적당하고 착화감은 기대이상 좋아요.\n약간 유광이라 참고하시고 더비슈즈는 첨인데 입문용으로는 부담없이 잘 신고다닐거같습니다.',
#   5],
#  ['52502242',
#   '키높이같은거는 잘안하고 다니는 터라 잘몰랐는데 이거신고 4cm위의 공기가 이렇게 상쾌하단걸 알게되었습니다.\n\n폭신하니 편하고 발볼도 딱맞고 조금더 뭉툭하길 바랬지만 이것도 매력있게 이쁘네요....더보기',
#   5],
#  ['52288713', '배송도 빠르고 신발도 이뻐요 편하게 신을 수 있어요', 5],
#  ['51871492', '발이 되게 편하고 키높이가 많이되서 좋은거같아요', 5],
#  ['51618588', '일반 구두와 다르게 발바닥이 편안하여 출퇴근용으로 자주 신고 있어요 !', 5],
#  ['51570988', '첼시부츠 처음 신어볼려고 고르다가 샀는데\n이쁘고 사이즈도 잘 맞는거 같습니다!', 5],
#  ['51483100', '이쁘고 뻘리왔네요 신을때마다 만족하고있습니다', 5],
#  ['51234244',
#   '척화감이 아주 좋아요\n발 아플 걱정은 없는거 같습니다\n광이 생각보다 많이 나는게 제 기준에서는 조금 아쉽네요',
#   5],
#  ['51068812',
#   '추가로 사이즈 255 신는데 260 신으니까\n편하게 딱 맞아요\n고민하지 마시고 255 신는분들은 260 가시면 될것 같아요...더보기',
#   5],
#  ['51013664', '이뻐요 착화감 나쁘지 않고 발 뒤꿈치 안까져서 좋아요', 5],
#  ['51013809', '이뻐요 착화감 나쁘지 않고 발 뒤꿈치 안까져서 좋아요', 5],
#  ['50993886', '적당하고 이쁨 이 가격대엔 만족 저번에 산 거는 뒷꿈치 다까졌는데 이건 그건 덜항', 5],
#  ['50842048', '가격이나 키높이 부분은 좋은데 오룬쪽 발가락이 너무 아파요', 5],
#  ['50775191', '전에 샀던 신발 착화감이 너무 좋아서 믿고 구매했습니다. 역시 너무 좋네요', 5],
#  ['50775184', '전에 샀던 신발 착화감이 너무 좋아서 믿고 구매했습니다. 역시 너무 좋네요', 5],
#  ['50737607', '착용감 적당해서 좋았고 디자인 색감 모두 이쁩니다!', 5],
#  ['50734857', '전에 샀던 신발 착화감이 너무 좋아서 믿고 구매했습니다. 역시 너무 좋네요', 5],
#  ['50300302', '구두치고 편안하게 잘맞아요 ~~ :)\n높이도 적당한 것 같습니다', 4],
#  ['50300284', '구두치고 편안하게 잘맞아요 ~~ :)\n높이도 적당한 것 같습니다', 5],
#  ['50240200', '가죽이 벗고신기 편하네요!!! 한달 넘게 자주 신었는데 구겨짐이 심하진않아요 잘신겠습니다', 5],
#  ['50221617', '볼드해서 어디든 어울려요 자주 신을것 같아요 뒤꿈치 약간 까지긴해도 좋아요', 5],
#  ['50073939', '제 발사이즈가 250인데 딱맞게 신으면 안될꺼같은 생각도 드네요', 4],
#  ['49940397', '구두는 발이 아파서 다른신발 찾아보다가 발견했는데 발이 확실히 편해요', 5],
#  ['49791590', '발등이 좀 작아요\n오래신으면 늘어날것같긴해요\n굽이 좀 있어요', 4],
#  ['49753696', '원래 신발 280 신고 280시켰는데 발등이 조금 작아요\n계속신어서 늘리면 늘릴수있을것같아요', 4],
#  ['49691001', '평소 운동화 285-290 신고 발볼 넓은 편인데 290주문햇습니다~ 사이즈 딱 편하게 신ㄱㅣ 좋아요', 5],
#  ['49516884', '잘 산거 같아요 두음에도 다른걸로 도전해볼게요 많이\n파세여', 5],
#  ['49422172', '무난하니좋습니다.\n데일리로 신기좋아요 편하구', 4],
#  ['49094294', '더비구두 처음샀는대 진짜 너무 편합니다 이가격에 이렇게 편할수없어요', 5],
#  ['48780094', '예쁘고 좋네요~사이즈도 적당합니다! 마음에 드네요~!', 5],
#  ['48667128', '포장은 쫌 반품했던거온것같은 느낌이네요\n구두치곤 편한데\n박스도 너무헐어있고 받는입장에서 기분이썩', 2],
#  ['48633066', '쉐잎이 좋아서 샀습니다. 좋은 더비에요 어디에나 어울려요', 5],
#  ['48514625', '가성비 좋으면서 이쁘게 신기 좋은 구두입니다. 추천드려요~', 5],
#  ['48368519', '너무너무 좋네요 또 사고싶어요 포장도 꼼꼼해요', 5],
#  ['48103965', '발아플까봐 걱정되서 평점 제일 좋은걸로 샀는데 편하고 이뻐요.키높이 효과도 있네요', 5],
#  ['48103958', '발아플까봐 걱정되서 평점 제일 좋은걸로 샀는데 편하고 이뻐요.키높이 효과도 있네요', 5],
#  ['48103951', '발아플까봐 걱정되서 평점 제일 좋은걸로 샀는데 편하고 이뻐요.키높이 효과도 있네요', 5],
#  ['48027065', '전에 로퍼 260으로 구매해서 사이즈 선택에 불편함은 없었네요 키높이 되고 좋아요', 5],
#  ['47956712', '푹신푹신하고 실제로 신어보니 사진보다 더 예뻐요', 5],
#  ['47880575', '고민을 많이 해서 샀는데 정말 만족스럽네요 사길 잘했어요', 5],
#  ['47798243', '배송도 빠르고 전반적으로 편한 느낌입니다.\n새 구두에 적응을 잘 해 보겠습니다.', 4],
#  ['47785381', '착화감 좋고, 발이 안 아파서 좋아요! 살짝 큰 치수로 샀는데도 안 벗겨지고 편안합니다', 5],
#  ['47515204',
#   '265 운동화 착용합니다. 구두는 260 신어서 주문했는데 밑창이 두꺼워서 그런지 딱 맞는 느낌입니다. 조금\n불편하지만 신다보면 늘어 날 것 같아서 그냥 신을 것 같아요.',
#   5],
#  ['47383923', '할인할 때 사서 잘 신고있습니다\n좋아요~\n약간 크게 나옴', 5],
#  ['47343747',
#   '착화감이 진짜 미쳤습니다\n발 진짜 편해야 신는데 얘는 뛰어도 괜찮을 정도\n디자인도 무난하게 예뻐서 더 좋아요',
#   5],
#  ['47050120', '비오는 날 신고 다니기 좋아요. 출근은 해야하는데 등산화가 필요하다 이럴 때 좋어요', 5],
#  ['46700823', '선물로 드렸는데\n발볼 넓고 편하다고 합니다\n60대 어르신에게 선물했는데...더보기', 5],
#  ['46593086', '밑창 이슈만 없으면 참 좋은 신발인데ㅜㅜ 재구매만 몇 번째...', 5],
#  ['46269440', '가격대비 맘에듭니다\n발은 어쩔수없이 조금 아픕니다', 5],
#  ['46025700', '할인할때 삿는데 이쁘네요 입문용으로 좋습니다', 4],
#  ['45950729', '할인할 때 얼른 삿습니다\n맘에 드네여 리얼가죽인데', 5],
#  ['45844152',
#   '항상 여기서 로퍼 사는데 더비도 여기가 제일인 거 같아요. 끈 넣는 부분 마감이 부실한 거 같지만, 끈 묶으면\n어차피 너도나도 안보이는 부분이니까요 뭐',
#   5],
#  ['45752348', '더비슈즈는 처음인데 입문용으로 딱 적당한 재품인거같아요', 5],
#  ['45534948',
#   '최고의 구두!\n남자라면 하나쯤 갖고 있어야하는 구두!\n제가 발이 255라 50살까60살까 고민했다가...더보기',
#   5],
#  ['45527006', '남자라면 구두 하나쯤은 필수!\n무조건 사세요 진짜', 5],
#  ['45307649', '불편하지않고 키높이가 많이되수 좋네요 데일리로 신기도 조아요', 5],
#  ['45281788', '키높이도 적당하고 무엇보다 편한거같아서 좋네요', 5],
#  ['45266100', '박스가 다 구겨져서 왔네요 포장이 좀 아쉽습니다 이쁘긴합니다', 5],
#  ['45266089', '박스가 다 구겨져서 왔네요 포장이 좀 아쉽습니다 이쁘긴합니다', 5],
#  ['45264913', '가격에 비해서 질이랑 전체적으로 나쁘지 않은 거 같은데용? 사이즈도 발볼이 좀 있는 편인데도 괜찮아요!', 5],
#  ['45264886', '가격에 비해서 질이랑 전체적으로 나쁘지 않은 거 같은데용? 사이즈도 발볼이 좀 있는 편인데도 괜찮아요!', 5],
#  ['45242344',
#   '안창 높이가 어마어마하네요! 끼고 신으면 불편한데 빼고 신으니까 너무 편해요!! 조금 낮은 안창도 팔았으면\n좋겠어요ㅠ',
#   4],
#  ['45242312',
#   '안창 높이가 어마어마하네요! 끼고 신으면 불편한데 빼고 신으니까 너무 편해요!! 조금 낮은 안창도 팔았으면\n좋겠어요ㅠ',
#   4],
#  ['45211519', '이쁘고 좋은거같은데 빨리 걸으면 벗겨질거같음', 5],
#  ['45027890',
#   '사람마다 발 크기가 달라서 정확하지는 않지만\n평소 270 신는데 정사이즈로 가셔도 될거 같습니다!\n크게 나왔다는 얘기가 많아 1사이즈 다운했는데 좀 끼네요..',
#   5],
#  ['44699428', '가성비 더비슈즈의 정석 착화감도 준수하고 전투용으로 아주 합격!', 5],
#  ['44671379', '착화감이 좋아 벌써 세 번째 구매하고 있는데, 밑창이 금방 갈라지는 이슈가 있어 아쉽습니다.', 5],
#  ['44190429', '착용감도 좋고\n디자인도 좋고\n배송도 빨라요...더보기', 5],
#  ['44044270',
#   '무난하고 편하게 신을 수 있어요. 아무래도 엄청 비싼 더비슈즈보다는 부족할 수 있지만 입문자들은 이런거\n신어보는 것도 좋을 것 같습니다!',
#   5],
#  ['44037119', '배송빠르고 가격 적당하고 좋아요\n사이즈가 5단위면 좋았을껀데 약간 크네요', 4],
#  ['43978084', '간편히 무난하게 신을수있어요 사이즈는 정사이즈요~!', 4],
#  ['43909559',
#   '잇츠더 굿잡맨 입니다. 구두 아주 매니 안좋아하는 휴먼이지만 잇츠더 착화감 굿잡맨 사이즈 굿잡맨 생긴거\n굿잡맨맨이',
#   5],
#  ['43829634', '생각보다 너무 이뻐서 놀랐습니다 행사같은곳에 신고 가면 딱 좋을것 같습니다', 5],
#  ['43709187', '너무 뽀죡하지도 너무 둥글지 않은 딱 중간의 찾던 로퍼라 너무 마음에 듭니다', 5],
#  ['43635192', '발 볼도 적당하고 길이도 딱 좋고 아주 좋습니다! 굽도 높아서 키높이 좋아용', 5],
#  ['43468682', '더비슈즈 고민하다 이걸로 구입 했는데 생각보다? 편하고 좋습니다!', 5],
#  ['43396886', '이뻐요~ 정장룩 캐주얼정장 데이트 등등 다 잘 어울려요', 5],
#  ['43343077', '무난무난하고 전투용으로 신기 아주 좋습니다.\n발도 별로 안아파요', 5],
#  ['43343056', '무난무난하고 전투용으로 신기 아주 좋습니다.\n발도 별로 안아파요', 5],
#  ['43260812', '별기대없이 구매했는데 아주 만족스럽니다.\n데일리하게 자주 신고 다녀요~\n발도 안아파요!', 5],
#  ['43260201', '기대없이 산건데 생각보다 신고 다니기도 편하고\n어디에나 어울려요~\n가성비좋아요~', 5],
#  ['43218202', '구두가 필요했는데 너무 잘 산것 같아요 잘 신겠습니다', 5],
#  ['43200913', '편안하게 잘 입고 다니기 좋은 아이템 같습니다아', 5],
#  ['43147628', '구두가 이렇게 편할 줄은 몰랐어요 운동화처럼 신고다님', 5],
#  ['43121322', '데님 슬랙스 치노 다 어울리는 것 같아요 편해서 자주 신어요', 5],
#  ['43107184', '한치수만 크게신으면 딱맞을거같네요 푹신하고좋아요', 5],
#  ['43081117', '굽도 적당히 있고 푹신해서 자주신고있어요\n추천합니다', 5],
#  ['43041771', '생각보다 신었을때 편합니다. 다른 구두보다 발이 덜 아플 것 같아요.', 5],
#  ['43041760', '생각보다 신었을때 편합니다. 다른 구두보다 발이 덜 아플 것 같아요.', 5],
#  ['43036875', '착용감, 배송 기간, 디자인, 색상 모두 만족합니다. 추천합니다!!', 5],
#  ['43036840', '신발 디자인, 착용감도 좋아요\n배송도 빨라서 추천해요', 5],
#  ['43012528', '이정도 가격에 이정도 퀄리티면 정말 괜찮네요 싸게 잘샀어요', 5],
#  ['43000737', '그냥 가성비 더비슈즈 찾으시면 추천해요 불편하진 않아요', 5],
#  ['42993241', '신발 앞 쉐입이 둥글게 되어있어서 와이드 슬렉스와도 잘 어울립니다. 입문용으로 추천드립니다.', 5],
#  ['42799174', '키야 입문자입니다 당장 구매하십쇼 세일가에 샀는데 잘샀다고 생각듭니다.', 5],
#  ['42827208', '생각보다 괜찮습니다!\n출근할 때 거의 매일 신고있습니다.', 5],
#  ['42799136', '입문자입니다 첼시 다음으로 도전하는 것인데 받아보고 나니 정말 괜찮네요 ㅎㅎ', 5],
#  ['42766066', '입문으로 샀는데 이뻐요~ 무광이라 마음에 듭니다 ㅎㅎ', 5],
#  ['42766056', '입문으로 샀는데 이뻐요~ 무광이라 마음에 듭니다 ㅎㅎ', 5],
#  ['42703577', '가죽이 살짝 약해서 오래 못신을수도 있을것 같지만 입문용으로는 강추입니다.', 5],
#  ['42691946', '저렴하게 구매했습니다 잘 신고다닐게요 감사해요', 4],
#  ['42691910', '몇번씩 재구매하는 제품입니다 저렴하게 잘\n구매했어요', 4],
#  ['42687559', '착화감이 너무 편하고 좋아요! 다른 구두 종류보다 발이 훨씬 덜 아파요', 5],
#  ['42640987', '입문용 구두인데 생각보다 편해서 놀랐습니다 좋아용', 5],
#  ['42637701', '생각보다 퀄리티 좋아요 저렴한 가격에 신기좋아요', 5],
#  ['42633007', '신발이 너무 가볍고\n편안해요 다만 험허게 신는다면 오래 못신을거같아요', 5],
#  ['42603422', '아주마음에 듭니다 가성비 최고구요 고급스러워 보여서 더 좋습니다', 5],
#  ['42603404', '아주마음에 듭니다 가성비 최고구요 고급스러워 보여서 더 좋습니다', 5],
#  ['42603368', '아주마음에 듭니다 가성비 최고구요 고급스러워 보여서 더 좋습니다', 5],
#  ['42349037', '굽도 높고 샹각보다 푹신해서 신기 좋고 가성비 갑인 것 같아요', 5],
#  ['42282405', '너무너무 마음에 들어요 데일리로 무난히 좋습니다', 5],
#  ['42265770', '신어봤는데 편안합니다 굽도어느정도있어서 저는 만족합니다', 5],
#  ['42265738', '신어봤는데 편안합니다 굽도어느정도있어서 저는 만족합니다', 5],
#  ['42196875', '키높이가 꽤 있어서 좋아요 입문용으로 좋은거같아요', 4],
#  ['42196859', '키높이가 꽤 있어서 좋아요 입문용으로 좋은거같아요', 4],
#  ['42072777', '한치수크게 신는게 좋으실거에요\n딱맞게신으면 살짝 끼는느낌', 5],
#  ['41938489',
#   'n년차 이브랜드만 구매중인 사람이에요 6켤레 이상 산것같은데 밑창 내구도가 낮아서 1년정도 지속적으로 신으면\n밑창이 상해서 계속 구매하게되는 대신 살면서 샀던 신발중 손에 꼽게 편해요 운동화급!',
#   5],
#  ['41831187', '발도 편하고 정사이즈로 신으면 딱 좋은것같아요!', 5],
#  ['41816348', '그냥 가성비 더비슈즈 찾으시면 추천해요 불편하진 않아요', 5],
#  ['41793976', '발도 편하고 색감도 괜찮아서 즐겨 신고 있습니다!', 4],
#  ['41746180', '일단 오래 신어도 발이 안 아프고 편안해서 좋고요, 키 높이 효과도 괜찮습니다. 가성비 굿!', 5],
#  ['41706292', '색감 너무 이쁘고 핏도 제가 바라던 핏이에요\n강추드려요!', 5],
#  ['41706274', '색감 너무 이쁘고 핏도 제가 바라던 핏이에요\n강추드려요!', 5],
#  ['41680959', '남친 사주려고 선물 했어요ㅎㅎ 만족해 합니다! 이뻐용ㅎㅎ', 4],
#  ['41664291', '재질상 약간의 유광 느낌이 어색하지만 점차 사라지려나요? 점잠 맘에 들길 바란답니다;', 4],
#  ['41663868', '빛에의해 약간 유광 느낌이 개인적으로 살짝 어색합니다;', 4],
#  ['41662744', '이미 표면에서 약간 유광 느낌이 원했던 모습이 아니네요; 점차 사라지겠죠~', 4],
#  ['41653573',
#   '발이 크신분들은 사시면 살짝 놀랄수도 있다는점 주의하시구요 !! 저는 정장에 신고 다니는데 나쁘진 않다.\n가성비다 라구 말할께요',
#   5],
#  ['41652121', '굽이 좀 있고 그래서 키가 커보이네요\n행사용으로 잘신었어요', 4],
#  ['41552721', '재구매인데 나쁘지 않아요 가성비도 좋고 출근용으로 쓰는즁이에여', 5],
#  ['41495682', '얇아서 막 고급진 느낌을 받을 수는 없지만 가격상의 이점이 있으니까 적당한 듯 싶네요', 5],
#  ['41448554', '너무 이뻐요 너무 이뻐요\n너무 이뻐요 너무 이뻐요', 5],
#  ['41409050', '색깔, 사이즈 전부 마음에 드네요. 오랜만에 옷 사입네요.', 5],
#  ['41350976', '데일리로 신으려고 구매했는데 매우 만족합니다 이뻐요', 5],
#  ['41344151', '후기가 늦었는데 편하게 데일리로 잘 신고 있습니다', 5],
#  ['41290564',
#   '군화 300, 운동화 290 신던 사람입니다. 사이즈에 대한 걱정을 많이했는데 딱 맞네요. 발볼은 좀 있는 편입니다.\n참고하셔서 구매하시면 될거같습니다!',
#   5],
#  ['41275807', '입문용으로 신기 좋아요\n도전해보세요 대신 짧은양말신으면 뒷꿈치 아파요', 5],
#  ['41274025', '기본템으로 더비슈즈 찾다가 가죽소재라 구매했습니다. 착화감 괜찮네요', 5],
#  ['41274019', '기본템으로 더비슈즈 찾다가 가죽소재라 구매했습니다. 착화감 괜찮네요', 5],
#  ['41274016', '기본템으로 더비슈즈 찾다가 가죽소재라 구매했습니다. 착화감 괜찮네요', 5],
#  ['41246817', '발볼이 넓은 편인데 한치수 위로 사니까 너무 잘맞고 일단 가성비좋은 예쁜 신발입니다', 5],
#  ['41244558', '가성비 너무 좋은데 너무 예쁜 신발 잘 고른거 같아요', 5],
#  ['41224575', '입문용으로 샀습니다. 가격대비 아주 좋은 착용감이고 270 정사이즈 발을 가져서 실패없이 구매했습니다.', 5],
#  ['41182260', '아주 편하고 이뻐요 다음에 다 쓰면 재구매의사 있습니다', 5],
#  ['41181301', '아주 편하고 이뻐요 다음에 다 쓰면 재구매의사 있습니다', 5],
#  ['41181287', '아주 편하고 이뻐요 다음에 다 쓰면 재구매의사 있습니다', 5],
#  ['41167843', '사이즈 딱맞고 예쁘네요 마감도 좋고\n만족합니다!!!', 5],
#  ['41162883', '발이 편하고 착화감이 좋네요. 잘 신을게요 감사해요~~', 5],
#  ['41147255', '다른 후기 평들처럼 가성비 좋고 전투화로 신기 좋아요', 4],
#  ['41139340', '구두와 운동화의 중간 정도의 편안함이고 발볼은 살짝 넓어요', 5],
#  ['41139274', '운동화와 구두 중간정도의 편안함이에요 발볼은 넉넉해요', 5],
#  ['41046972', '가성비 아주 좋은 제품같아요\n라이트하게 신기 좋아요.', 5],
#  ['41014534', '가격대비 괜찮아요.\n전체적으로 디자인이 마음에 들어요.', 5],
#  ['40950639', '오래 신고 걸었는데도 발이 불편하지 않더라고요!!!너무 좋은거 같습니다!', 5],
#  ['40949888', '저번에 처음 구매했다가 이번에 재구매 해서 쓰고있어요 편합니다', 4],
#  ['40917154', '사이즈도 딱맞고 쉐입이 너무 예뻐요 잘 신을게요', 3],
#  ['40881284', '가격에 비해 튼튼하고 착용감도 좋아요 낡으면 또 살 듯', 5],
#  ['40881198', '가격에 비해 튼튼하고 착용감도 좋아요 낡으면 또 살 듯', 5],
#  ['40806518', '가격에 비해 굉장히 편하고 보기에도 고급져요 자주 신을것같아요', 5],
#  ['40798727', '가격대비 좋아서 가성비로 신고다니면 딱인듯 합니다', 4],
#  ['40770997', '사이즈 적당하고 다른 더비에 비해 착화감이 좋습니다', 5],
#  ['40758666', '그냥 초보자가 신기에 무난무난해여 그렇디않슺니까?', 4],
#  ['40730559', '신발 생각보다 가볍고 착화감 좋아요 좀 큰데 꽉끈해서 신으면 괜찮아요', 5],
#  ['40730553', '사이즈 생각보다 좀 큰데 꽉끈해서 신으면 괜찮아요 신발도 가볍고 착화감도 괜찮네요', 5],
#  ['40722767', '출근할때 신으려고샀는데 생각보다 편하게 잘신고다녀요~ 가성비 좋습니다', 5],
#  ['40716232', '이쁘기도하고, 착용감도 편해서 자주 신을것같아요', 5],
#  ['40715151',
#   '신발 위쪽 가죽 본드칠 된 부분이 쌀짝 떨어질려 하는데 끈으로 꽉 조이니깐 문제는 없네요. 그래도 가격 대비\n퀄리티가 좋아요.',
#   5],
#  ['40703841', '딱 베이직한 더비슈즈 느낌! 생각보다 너무너무 편안해서 여행 내내 잘 신고 다녔습니당!', 5],
#  ['40666804', '제가 신으려고 산 건 아니지만, 구두가 너무 편하고 이쁘네요.. 가격도 저렴해서 좋습니다.', 5],
#  ['40666738', '제가 신으려고 산 건 아니지만, 구두가 너무 편하고 이쁘네요.. 가격도 저렴해서 좋습니다.', 5],
#  ['40666714', '제가 신으려고 산 건 아니지만, 구두가 너무 편하고 이쁘네요.. 가격도 저렴해서 좋습니다.', 5],
#  ['40654267', '기본 더비 슈즈로 시작하기 좋은거 같네요! 예쁩니다', 4],
#  ['40652329', '더비 처음 신어보는데 이뻐요!! 친구 결혼식이 있어서 샀는데 편안하게 신고 갈 수 있을 것 같아요~', 5],
#  ['40639159', '발이 너무 편해서 좋아요! 앞으로 자주자주 신을 것 같아요!', 5],
#  ['40638841', '처음 구두 사서 신어보는데 일단 발이 너무 편해서 좋은 것 같아요!', 5],
#  ['40626189', '친구 생일선물로 샀는데 친구도 마음에 들어합니다.', 5],
#  ['40555484', '이런류의 신발을 처음 신어봤는데\n가격대비 이쁘고 착화감도 편해요', 5],
#  ['40555257', '이런류의 신발을 처음 신어봤는데\n가격대비 이쁘고 착화감도 편해요', 5],
#  ['40452843', '무난하게 신기 좋은 구두입니다 잘신고있습니다', 5],
#  ['40449359', '계속 잘 신고 있습니다! 감사합니다. 잘 어울리네요', 5],
#  ['39597873', '가성비 구두로 완전 추천드립니다 착화감도 굉장히 편안해요', 5],
#  ['40441900', '생각보다 말랑말랑하고 땀이 차는 재질인 것 같은데 가격 생각하면 퀄리티는 좋습니다!', 5],
#  ['40402367', '구두같지 않고 되게 푹신해서 좋아요 디자인도 무난하고 입문용으로 좋아요!', 5],
#  ['40402321', '구두같지 않고 되게 푹신해서 좋아요 디자인도 무난하고 입문용으로 좋아요!', 5],
#  ['40390430', '가죽 소재가 약간 얇습니다. 편안하고 아주 기본적인 느낌의 구두입니다', 5],
#  ['40389655', '가성비 굿 아이템잊니다. 활용도도 좋아서 두번째 구매해요!', 5],
#  ['40103500', '두번째 구매입니다. 여전한 퀄리티네요. 잘 신겠습니다!', 5],
#  ['40321101', '상품 받으셨을때 사이즈 잘 확인하세요\n\n사이즈가 한사이즈 크게 배송되었네요...더보기', 3],
#  ['40261358', '투박하지만. 느낌내기 좋음. 키가 많이 커짐 ㅎ 안전화냐고 가끔 사람들이 물어봄', 5],
#  ['40236850', '더비 슈즈 처음 입문했는데 생각보다 너무 편하고 안아파요', 5],
#  ['40228718', '생각보다 편합니다 근데 색상은 반타블랙이 아닌듯 어쨌든 개추', 4],
#  ['40216855',
#   '신어본 구두 종류중에선 가장 폭신하고 편안한 것 같아요. 갠적으로 사이즈는 원래 신는대로 가면 딱 맞는다고\n느꼈습니당 광택도 과하지 않게 나는 정도라 만족합니다',
#   5],
#  ['40214132',
#   '나이키 조던 280mm, 에어포스 275mm에 발볼은 중간 정도인데 280mm사이즈 길이 살짝 남지만 편안하게 잘\n맞네요. 디자인 만족하고 품질도 나쁘지 않은듯 하고 그저 가성비가 좋다는 느낌입니다.',
#   5],
#  ['40208670', '생각보다 너무가볍고 편합니다. 가성비 좋은듯 해요', 5],
#  ['40150762', '무난하게 더비슈즈 입문용으로 괜찮아요\n걸을때도 편해요', 5],
#  ['40148097', '가격도 착하며 착화감도 편하고 첫 더비로 신기 좋습니다.', 5],
#  ['40148069', '가격도 착하며 착화감도 편하고 첫 더비로 신기 좋습니다.', 5],
#  ['40133975', '생각 한 거랑 같고 크기도 적당하고 심플 하니 좋아요 가성비 최고', 5],
#  ['40121826', '사이즈가 마음에 드네요 가겨대비 굉장히 만족해요', 5],
#  ['40117552', '이 가격에 이 정도 퀄리티와 착화감이면 만족합니다.', 4],
#  ['40116593', '착화감 진짜 너무 편하고 입문용으로 신기 좋아용', 5],
#  ['40116512', '착화감 엄청편하고 가격도 저렴해서 입문용으로 진짜 좋아용', 5],
#  ['40116292', '착화감 진짜 엄청 편하고 가격도 저렴해서 입문하기 좋아용', 5],
#  ['40074490', '오래 신어도 발이 안아파서 너무 좋습니다. 이쁜건 기본이고요!', 5],
#  ['39982335', '가죽상태 좋아서 정사이즈 추천드리고요.\n이쁘게 잘만들어졌습니다.', 5],
#  ['39974978', '두번째 구매입니다. 여전한 퀄리티네요. 잘 신겠습니다!', 5],
#  ['39966775', '생각보다 편하고 광택도 제가 원하는 정도인것 같아요', 4],
#  ['39958400', '신어본 더비 중에 제일 편하고 푹신푹신해서 좋아요!!', 5],
#  ['39954768', '신발 너무 예뻐요~~ 차려입어야 할때 입고 가면 좋아요', 5],
#  ['39945655', '가성비 좋고 착화감 운동화처럼 편안해서 좋아요', 5],
#  ['39939604', '생각보다 이쁘고 코디하기 쉬울꺼 같아서 좋아요', 5],
#  ['39930072', '엄청 편한건아니지만 예쁘게 신을수있을거같아요:)', 5],
#  ['39907536', '배송이 빨라서 좋구 실물이 더좋은데 생각보다.사이즈가 커서 아쉬워용', 5],
#  ['39903811', '가성비 좋고요 저는 나*키 275 신는데 한 치수 작게 주문했는데 딱 맞네요', 4],
#  ['39903721', '4번 신어본 결과 가성비 좋아요 발도 안아프고 좋네요', 4],
#  ['39891906', '핏이 정말 이쁜 더비슈즈\n착화감 예술입니다~\n편하고 키높이 효과까지 ㅎㅎ', 5],
#  ['39889104', '앞부분이 둥글해서 살짝 정사이즈보다\n큰감이 있네요', 4],
#  ['39864999',
#   '적당히 알바할 때 구두 필요해서 샀는데 편하고 굽이 놉지 않아서 아무렇게 신기에 좋아요 보기에도 이쁘니\n편안함과 멋을 함께 챙길 수 있어용',
#   5],
#  ['39863736', '착화감 별 기대 안 했는데 생각보다 너무 편하네요 디자인도 깔끔해서 좋아요', 5],
#  ['39860247', '어느 정도 굽이 있는데도 착용감 편하고 좋습니다', 5],
#  ['39856125', '굿이에용 딱좋기는한데 많이걸어다닐거면 힘들어용', 4],
#  ['39843614', '인생신발입니다.\n출퇴근할때 맨날 신어요. 내구성도 굿', 5],
#  ['39809979', '데일리 슈즈로 딱입니다\n가격도 저렴하게 사서 좋네요\n굽이 딱딱하지 않아서 좋아요', 5],
#  ['39796519',
#   '상품 좋아요. 키높이도 되고 캐쥬얼이나 정장 어디에도 어울려요.\n\n그런데 신발 끈이.. 일반 운동화 끈이 와서 좀 아쉬워요.',
#   4],
#  ['39762559', '사이즈가 크게나와서 발이 아프지 않아요. 정사이즈 추천드립니다', 5],
#  ['39743045', '가성비 좋음 오래 신을 수 있을 것 같진 않음 깔창에서 오는 쿠션감', 4],
#  ['39741767',
#   '일단 가격이 마틴 1/3값이라 가성비는 훌륭한데 아무래도 어쨋든 구두이다보니 퀄리티 기준이 높게 되네요 가죽\n질감이 좋아보이진 않는데 질이 들어봐야 알 것 같고 바닥 마크는 비브람 느낌으로 노란색을 썼는지 모르겠는데\n좌우 방향이 같은 개체가 있을까 싶네요 사이즈는 5미리라 반업/반다운 고민하다 반다운했는데 꽉끼게 맞음',
#   4],
#  ['39728773', '사이즈가 10단위라 좀 큰거 같긴한데\n편하게 신을게용 이쁩니다', 5],
#  ['39701604', '신발 가격대비 정말 괜찮아요 하루 신어봣는데 대만족', 5],
#  ['39696999',
#   '저렴한 가격에 잘 샀습니다. 일단 신발이 되게 편해서 신기에 거부감이 없어서 너무 좋아요. 잘 신고 다니고\n있습니다',
#   5],
#  ['39660605', '굽이 생각보다 조금 높네요 그래도 가격대비 신을만합니다', 5],
#  ['39660603', '굽이 생각보다 조금 높네요 그래도 가격대비 신을만합니다', 5],
#  ['39660592', '굽이 생각보다 조금 높네요 그래도 가격대비 신을만합니다', 5],
#  ['39642135', '처음 구두 입문인데 싸고 좋아요! 살짝 딱딱하지만 데일리로 좋은 것 같습니다!', 3],
#  ['39616944', '그냥 무난한 워커 입니다.\n여러모로 잘 신겠네요.\n사이즈도 맞고 색상도 잘나왔습니다....더보기', 4],
#  ['39613198', '휘뚜루 마뚜루 신기 아주 좋습니다\n이정도 가격에 딱좋게 신을수있습니다^^=', 5],
#  ['39597676', '굽 높아서 좋고 착화감 편안해서 좋습니다 구두치곤 굉장히 편한 축에 속하는 것 같아요', 5],
#  ['39597487', '튼튼하고편해요\n몇달째 신고 있는데도 흠집도 없고 길도잘들여지네요', 5],
#  ['39596498', '빠르게 배송 받았고 착화감이 적당히 폭신하면서 좋네요.\n외출은 아직 안해봤지만 좋습니다!!', 5],
#  ['39583977', '발볼이 넓어서 항상 한사이즈업 해서 신는데 정사이즈로 신어도 편안하네요', 5],
#  ['39583936', '발볼이 넓어서 항상 한사이즈업 해서 신는데 정사이즈로 신어도 편안하네요', 5],
#  ['39583840', '발볼이 큰편이여서 항상 사이즈업해서 신는데 정사이즈로 신어도 편안하네요', 5],
#  ['39581535', '구두 처음 구매해봤는데 가격대도 적당하고 입문템으로 딱이에요', 5],
#  ['39581329', '구두 처음 구매해봤는데 가격대도 적당하고 입문템으로 딱이에요', 5],
#  ['39550808', '가성비 최고네요 신발도 너무 이쁘고 나중에 재구매 할거같네요', 5],
#  ['39524586', '주변 지인 추천으로 샀는데 가격대비 가성비 확실히 좋습니다', 5],
#  ['39510414', '발이 엄청 편해요!!딱 좋습니다 ㅎ.ㅎ\n디자인도 이쁘고~자주신을꺼같아요', 5],
#  ['39510386', '발이 엄청 편해요!!딱 좋습니다 ㅎ.ㅎ\n디자인도 이쁘고~자주신을꺼같아요', 5],
#  ['39503454', '편안하고 이뻐요. 데일리로 활용잘할거같아요. 무슨바지든 잘어울려요', 5],
#  ['39503446', '편안하고 이뻐요. 데일리로 활용잘할거같아요. 무슨바지든 잘어울려요', 5],
#  ['39503427', '편안하고 이뻐요. 데일리로 활용잘할거같아요. 무슨바지든 잘어울려요', 5],
#  ['39451718', '아주 좋습니다. 딱 원하는 핏이에요. 이쁘게 입겠습니다.', 5],
#  ['39434598', '키가 커지는느낌 근데 발뒤꿈치가 너무 아프네요.\n가격대비 가성비 아이템', 5],
#  ['39379535',
#   '신발 265-270신는데\n이건 270하니까 여유 있게 신을 수 있네요\n부츠는 10업해서 신는 편인데...더보기',
#   5],
#  ['39379438', '디자인 이쁘게 잘 빠졌고\n착화감 나쁘지 않아요...더보기', 5],
#  ['39338640', '아주 편하고 잘 애용하겠습니다 감사합니다 잘 신을게용', 4],
#  ['39321469', '입문용 더비로 하나 구입하는거면 추천드립니다', 5],
#  ['39293440', '라이즈도 좋고 편해요 잘 샀습니다 재구매도 의사 있아요', 5],
#  ['39267272', '가성비로 정말 최고네요. 데일로 편하게 신고있습니다. 많이 파세요 ㅎ', 4],
#  ['39222865', '가성비 좋은 더비슈즈네요 굽도 있는 편이고 착화감 편해서 좋아요', 4],
#  ['39095204', '발볼이 넓은편이라 한치수 업했는데, 정사이즈로 사셔도 괜찮을 것 같아요. 가격대비 좋은 더비슈즈입니다.', 5],
#  ['39074859',
#   '전투용으로 좋은것 같습니다.\n단지 발등이 좀 높은 분들은 불편할거같아요\n발등이 좀 아픈데 그냥 신습니다',
#   4],
#  ['39060871', '불편하지도 않고 착용감이 딱 좋아서 오래신어도 괜찮을꺼 같아요^^', 5],
#  ['39055811', '그냥 딱 가격정도 합니다. 그래도 이 가격에 간단히 신을 구두라면 만족합니다', 4],
#  ['38970745', '발이 편해서 자주 손이 갈 거 같습니다 구두가 필요한 날에 제 역할을 해줄만한 아이템입니다', 5],
#  ['38970419',
#   '착화감이 거의 운동화만큼 편한거 같아요 사이즈도 정사이즈로 보시면 될 거 같구요 구두가 필요한 날에 편하게\n신기 좋을거 같습니다',
#   5],
#  ['38956907', '세일할때 구매해서 저렴하게 가성비있게 잘 구매한듯 하네요.', 5],
#  ['38934269', '청바지에 입기에도 잘 어울리고 좋네요 추천드립니다', 5],
#  ['38921934', '저렴한 가격에 잘 사서 자주 신고 다니는데 예뻐서 맘에 들어요', 5],
#  ['38920581', '원래 280신는데 그대로 사니까 딱 적당합니다 좋아요', 5],
#  ['38879984', '가성비 짱입니다 발도 편하고 잘 신고있어 좋습니다', 5],
#  ['38877543', '잘 받았어요 마감처리가 참 아쉽지만 나쁘진 않아요', 4],
#  ['38877536', '잘 받았어요 마감처리가 참 아쉽지만 나쁘진 않아요', 4],
#  ['38861264',
#   '더비슈즈를 저렴하게 입문할 수 있어서 되게 좋았던 것 같습니다. 디자인도 무난해서 포멀한 자리에 갈 때 신기\n좋습니다.',
#   5],
#  ['38810372', '가볍게 신기 좋은거같아요 가격도싸고 마음에드네요', 5],
#  ['38799319', '출근용으로 자주 신습니다. 착화감 좋아요. 편하네요.', 5],
#  ['38758468', '장시간 착용하고 걸어다녀도 발 아프지 않고 쿠션감이 좋아요.', 5],
#  ['38756811', '여기저기 스타일링하기 좋아요\n가성비 좋습니다', 5],
#  ['38756147', '원래 255신는데 250사니까 진짜 딱 맞았어요', 5],
#  ['38754835', '한번 신어봤는데 괜찮아요 무난합니다 이십자자', 5],
#  ['38750637', '더비 입문으로 딱 좋은 것 같습니다. 착화감도 굉장히 편안하네요', 5],
#  ['38749934', '더비 입문으로 딱 좋은 것 같습니다. 착화감도 굉장히 편안하네요', 5],
#  ['38727438', '사이즈 앞뒤길이가 좀 크긴한데 일부러 크게만든건지 커서 걸을때 타제품보다 훨신 편해요', 5],
#  ['38725920', '사이즈 굿 착화감 굿 발도안아프고아주만족스럽', 5],
#  ['38696610', '모양은 무난만 기본 구두입니다. 무엇보다 가격대비 가성비가 매우 좋습니다. 고급스러워요.', 5],
#  ['38671523', '발볼이랑 발등 높은편인데 하나도 안불편하고 잘 신고있습니다.평소 신발은 265신는데 260신어도 괜찮네요', 5],
#  ['38583498', '기본 블랙 더비슈즈로 추천합니다! 입문용으로 부담없고 좋아요:)', 5],
#  ['38575423', '생각한거보다 사이즈가 많이 커요 정사이즈에서 한사이즈 줄이시는게 나을거 같아용', 5],
#  ['38573842',
#   '구두 특성상 좀 딱딱한건 있는듯요 조금 발볼이 좁아서 크게 시켰는데 괜찮아요 대신 뒷꿈치는 어쩔수없이\n까지는듯요',
#   5],
#  ['38530943', '괜찮은것같아요 사이즈도 딱 맞고 편합니다추천', 5],
#  ['38507158', '외출용으로 신을만한 신발이 없어서 구매했는데 부담스럽지도 않고 데일리하게 신기 좋아요', 5],
#  ['38486253', '구두를 처음 사봤는데 입문용으로 딱 좋은거같아요 데일리로 신기에도 부답스럽지 않고 좋아요', 5],
#  ['38408449', '사이즈는 하나 작은게 좋은 것 같아요! 깔끔하고 예쁩니다', 5],
#  ['38380043', '이런저런 다괜찮은데 발바닥이 불편하긴함 아쉬움', 4],
#  ['38373868', '신발 깔끔하고 가성비 좋네요. 굽이 생각보다 높아서 조금 놀랐어요', 5],
#  ['38373850', '신발 이쁘네요. 편하고 굽이 높아서 키가 엄청 커져서 좋아요', 5],
#  ['38371522', '사이즈 적당하고 발도 편안하니 좋습니다\n추천합니다', 5],
#  ['38339238', '신발너무편합니다 자꾸왼쪽 발이 신발끈이풀리는데 그것만빼면 너무편합니다 새제품인데도 전혀안아픕니다', 5],
#  ['38334492', '키높이도 좀 있고 나름 디자인도 깔끔해서 가성비 제품입니다 ㅎㅎ', 4],
#  ['38301725',
#   '더비 치고 착화감도 괜찮고 좋네요 사이즈는 조금 크게 나온 거 같아요 정사이즈 구매하시면 널널하게 신을 수\n있어요',
#   5],
#  ['38290415', '이정도 가격에 퀄리티가 정말 미쳤어요 그리고 확실히 착화감이 좋아요', 5],
#  ['38246158', '동글동글 입기\n좋아요. 캐주얼이나 포멀이나 둘 다 매치\n가능해요', 5],
#  ['38209491', '편안, 무난, 가격도 합리적, 더비 없으시면 후회는 안할듯.', 5],
#  ['38205924', '다좋은데 입문용으로 오래걸을시 발이조금아파요', 4],
#  ['38205913', '괜찮은데 입문용으로 그런데 발이 조금 아픔 오래걸을시.', 4],
#  ['38204733', '더비슈즈 입문용으로 샀는데\n맘에듭니다. 착화감이좋아요', 5],
#  ['38203524', '더비슈즈 처음 구매해보는데 가성비 좋게 잘 산 것 같습니다!', 5],
#  ['38202102', '보통 처음신으면 뒤꿈치 아픈데, 이건 그런게 없는거같아요. 부드러우면서 빳빳하게 신발 잘 만드신듯 ,', 5],
#  ['38190095', '더비슈즈 처음 구매해보는데 가성비 좋게 잘 산 것 같습니다!', 5],
#  ['38190028', '더비슈즈 처음 구매해보는데 가성비 좋게 잘 산 것 같습니다!', 5],
#  ['38147869', '친척 결혼식때문에 급하게 구입했는데 생각보다 괜찮네요 가상비 굿굿!!', 5],
#  ['38131869', '지인 결혼식때문에 급하게 구매했는데 생각보다 편해요 가성비 굿', 5],
#  ['38119352', '유광이 아니라 무난하고 착화감 좋고 키높이 기능이 있어서 딱 좋습니다.', 5],
#  ['38119039', '고급스러워보이고 착화감이 좋아요\n키높이 기능이 있어요', 5],
#  ['38077516', '색감 잘 나오고 사이즈도 딱 맞아서 전투용으로 신기 너무 좋아요', 5],
#  ['38077404', '사이즈는 운동화와 동일하고 너무 예뻐서 입문용으로 좋아요', 5],
#  ['38065795', '기대 이상으로 착화감이 좋습니다. 첫날 신었을 때부터 부드러운 느낌이 들어 좋아요', 5],
#  ['38063580', '굿굿따리 엄청 고급져보여요 코디하기도 딱 좋음', 5],
#  ['38063545', '신발 엄청 예쁘고 고급스러워요 코디하기도 좋고 굿', 5],
#  ['38052731', '무난하게 신기조아요ㅎㅎ 가성비좋습니다 또 만나요', 5],
#  ['38048109',
#   '굽이 있는 편이여서 그런지 기존 신발들 보다는 작은 감이 있긴 한데 가죽 질 좀 들이고 하면 괜찮을 것 같아요',
#   4],
#  ['38027993', '면접, 경조사용으로 구매했는데 가격대비 퀄리티도 좋고 착화감도 마음에 듭니다👍', 5],
#  ['38023853', '발볼이 적당하고, 사이즈도 정사이즈 입니다.\n만족합니다.', 5],
#  ['38023810', '발볼도 적당하고 스타일이 좋습니다.\n만족합니다.', 5],
#  ['38001621', '면접, 경조사용으로 구매했는데 가격대비 퀄리티도 좋고 착화감도 마음에 듭니다👍', 5],
#  ['37985365', '좋았어요 가성비 느낌으로 좋아요\n회사에서도 신고 일상에서도 신기\n아주 좋아요~', 5],
#  ['37969160',
#   '첼시 부츠 이후 첫 더비 부츠인데 발끝이 뾰족해서 너무 이쁘네요..! 살짝 기장 긴 바지랑 같이 코디하면 너무 이쁠\n것 같습니다 ㅎㅎ',
#   5],
#  ['37969097', '발끝이 둥글한 것보다 역시 살짝 뾰족한 구두가 더 예쁜거 같아요 ㅎㅎ', 5],
#  ['37966145', '가격대비 좋아요~ 색감도 적당 편안함도 적당 정사이즈 갔습니다', 5],
#  ['37958187', '원래 신발 265신는데 270은 약간 오버 사이즈 느낌이네용 오버로 갈려면 +5 딱 맞을려면 -5 고고', 5],
#  ['37958136', '구두인데 구두 같지 않을 정도로 편하고 너무 좋습니당', 5],
#  ['37947151', '구두 입문용으로 사봤는데 좋아요 착용감도 좋고 발볼도 넓어요 오래신으면 뒷꿈치가 아프긴한데 추천합니다', 5],
#  ['37935261', '진짜 운동화 신는 것처럼 너무 편해요!\n입문용으로 추천합니다', 5],
#  ['37931365', '사이즈 적당하고 발도 편안하니 좋습니다\n추천합니다', 5],
#  ['37927493', '착화감 별 기대 안 했는데 생각보다 너무 편하네요 디자인도 깔끔해서 좋아요', 5]]

# %%
# 리뷰 데이터 전처리 & 키워드 분석 수행
# [[review_id, text_sentence, review_category, rating],[ ], ...]으로 저장
processed_results = process_reviews_with_labels(review_data)

# %%
# 데이터 저장 방식 확인
for row in processed_results : print(row)
# Out:
# ['60041401', '슬랙스 바지 등에 신기에 무난합니다', ['디자인'], 5]
# ['60041401', '발이 아직 길이 안들어서 그런가 오래신지는 못하겠네요', ['사이즈', '내구성 및 품질'], 5]
# ['60022817', '이뻐서 재주문하고자 합니다', ['디자인'], 5]
# ['60022817', '이쁜제품 감사드려요', ['디자인'], 5]
# ['59758881', '크긴한데 입을만해요', ['사이즈'], 5]
# ['59758881', '색상 마음에 들고 만족합니다', ['디자인'], 5]
# ['59671660', '첫 입문 더비인데 편하고 가격대비 훌륭한 것 같아요', ['착용감', '가성비'], 5]
# ['59671660', '자주 신을 것 같아요', ['기타'], 5]
# ['59614714', '사이즈 잘 맞고 어느정도 키높이효과 잇어요', ['사이즈', '디자인'], 5]
# ['59614714', '좋아요', ['기타'], 5]
# ['59389900', '아주조아요', ['기타'], 5]
# ['59389900', '품질도 좋습니다', ['내구성 및 품질'], 5]
# ['59389900', '깔끔하구용 고마워요', ['기타'], 5]
# ['59327205', '잘사용하고있어요', ['기타'], 5]
# ['59327205', '감사합니다', ['기타'], 5]
# ['59327205', '제품이 사진과 같아요', ['기타'], 5]
# ['58969743', '정 사이즈로 주문하시면 됩니다', ['사이즈'], 5]
# ['58969743', '기본적으로 정장 구두라기 보다는 캐주얼', ['디자인'], 5]
# ['59020127', '저렴하게 좋은 제품 구매 했어요', ['가성비'], 5]
# ['59020127', '비슷한 가격대에서 최고예요', ['가성비'], 5]
# ['59020127', '많이 파세요', ['기타'], 5]
# ['58984930', '좋아요', ['기타'], 5]
# ['58984930', '색감도 예쁘고 여기저기 매치하기 좋네요', ['디자인'], 5]
# ['58969911', '정 사이즈로 가시면 되고 캐주얼 하면서 편안한 남성 구두를 찾는다면 대안이 없을 정도로', ['착용감', '사이즈', '디자인'], 5]
# ['58969814', '무신사에서 구매하고 만족하는 제품 중에 하나 기본적으로 편안하면서 캐주얼 하게 입고 싶을 때', ['착용감', '디자인'], 5]
# ['58926643', '지금까지 신었던 구두중에 발도 편하고 가성비도 훌류해요', ['착용감', '가성비'], 5]
# ['58926626', '지금까지 신었던 구두중에 발도 편하고 가성비도 훌륭해요', ['착용감', '가성비'], 5]
# ['58922693', '보기보다 가볍고 편해요', ['착용감'], 5]
# ['58922693', '아무 옷에나 다', ['디자인'], 5]
# ['58922693', '잘 어울리는 기본템입니다', ['디자인'], 5]
# ['58922465', '사이즈는 넉넉한 편이고 굽이 있는 편인데 반해 가볍고 편합니다', ['착용감', '사이즈', '디자인'], 5]
# ['58922465', '치노 셋업 데님 아무데나 다 잘 어울려요', ['사이즈', '디자인'], 5]
# ['58677455', '괜찮아요', ['기타'], 5]
# ['58677455', '가성비 좋은 상품이네용', ['가성비'], 5]
# ['58677455', '사이즈는 정사이즈로 하니 맞네요', ['사이즈'], 5]
# ['58585939', '이거 물건이네요', ['기타'], 5]
# ['58585939', '뒤꿈치 까질일없고 바닥면 푹신하고', ['착용감', '내구성 및 품질', '디자인'], 5]
# ['58555679', '사이즈 정사이즈이고 편안하네요', ['착용감', '사이즈'], 5]
# ['58555679', '딱딱하지않고 신을만합니다', ['착용감'], 5]
# ['58547949', '저렴한 가격에 가성비 좋은 구두입니다', ['가성비'], 5]
# ['58547949', '만족해요', ['기타'], 5]
# ['58486300', '발볼 때문에 275에서 280 신는 사람인데 270 정사이즈도 발볼이 적당하고 편해서 좋아요', ['착용감', '사이즈'], 5]
# ['58461470', '앞쪽 갈라짐', ['디자인'], 4]
# ['58461470', '상태에 따라 달라지는듯 가격대비 괞찮아요', ['가성비'], 4]
# ['58146908', '쉽게 쉽게 신기 편하고 가성비 구두 같은 느낌입니다', ['착용감', '가성비'], 5]
# ['58146908', '더비슈즈나 구두 입문할까 고민될 때 구매해서 신어보시면 높은 확률로 만족하실 거에요', ['가성비'], 5]
# ['57990919', '다른분들 리뷰보고 샀는데 착화감 좋습니다', ['착용감'], 5]
# ['57990919', '굽이높아 자연스런 키높이효과도 있고 디자인이 무난해서 출근룩에도 자연스러워요', ['디자인'], 5]
# ['57990919', '첫 더비슈즈였는데 대만족입니다', ['기타'], 5]
# ['57990928', '다른분들 리뷰보고 샀는데 착화감 좋습니다', ['착용감'], 5]
# ['57990928', '굽이높아 자연스런 키높이효과도 있고 디자인이 무난해서 출근룩에도 자연스러워요', ['디자인'], 5]
# ['57990928', '첫 더비슈즈였는데 대만족입니다', ['기타'], 5]
# ['57990898', '다른분들 리뷰보고 샀는데 착화감 좋습니다', ['착용감'], 5]
# ['57990898', '굽이높아 자연스런 키높이효과도 있고 디자인이 무난해서 출근룩에도 자연스러워요', ['디자인'], 5]
# ['57990898', '첫 더비슈즈였는데 대만족입니다', ['기타'], 5]
# ['57914368', '신발 편하고 좋네요', ['착용감'], 5]
# ['57914368', '사이즈도 디자인도 맘에들어요', ['사이즈', '디자인'], 5]
# ['57896928', '깔창있는 상태에서 끈있는 코부분이 타이트하게 제작되어있어 사이즈가 맞음에도 신발신기가 불가능할정도로 힘들었습니다', ['착용감', '사이즈'], 2]
# ['57896928', '결국 깔창을 빼고 신었는데 원래 이렇게 제작이 되는건지 아니면 제가 불량상품에 걸린건지 아쉬웠습니다', ['사이즈', '배송 및 포장 및 응대'], 2]
# ['57783017', '290 크긴 하네요', ['사이즈'], 5]
# ['57783017', '발 큰 사람들에겐 제격입니다', ['사이즈'], 5]
# ['57751214', '마무리 깔끔하고 보통 245 250 신는데 잘 맞습니다', ['착용감', '사이즈'], 5]
# ['57751214', '통바지에 잘 어울리겠어요', ['디자인'], 5]
# ['57751187', '발이 작은편인데 나름 크게 보이고 굽도있어 키높이효과도 있어요', ['사이즈', '디자인'], 5]
# ['57751187', '마무리 깔끔하고 흠잡을데 없네요', ['착용감'], 5]
# ['57728768', '가성비좋고 무난하게 편안해요', ['착용감', '가성비'], 5]
# ['57728768', '가볍고 경조사에 신고가기 좋아요', ['착용감'], 5]
# ['57727367', '더비슈즈 처음 사봤는데 발도 편하고 코디하기 좋네요', ['착용감', '디자인'], 5]
# ['57653420', '가성비로 출근할 때 신기 좋은 구두입니다', ['가성비'], 5]
# ['57653420', '편하고 좋습니다', ['착용감'], 5]
# ['57489509', '더비슈즈 이뻐요', ['디자인'], 5]
# ['57489509', '로퍼랑 같이 번갈아가면서 신는데 편해요', ['착용감'], 5]
# ['57453186', '생각했던것보다 안크고 딱맞아요', ['착용감', '사이즈'], 5]
# ['57453186', '편해요', ['착용감'], 5]
# ['57264666', '구두는 처음신어보는데 가볍고 편해서 좋네요', ['착용감'], 5]
# ['57217522', '사이즈 적당히 잘 맞고 원하던 아이템입니다 마음에 들어요', ['사이즈'], 5]
# ['57206842', '무난해서 아무데나 신기 편합니다 사이즈도 정사이즈 입니다', ['사이즈'], 5]
# ['57197500', '만족합니다', ['기타'], 5]
# ['57197500', '너무좋아요', ['기타'], 5]
# ['57197500', '저렴하게 잘 구매했어요', ['가성비'], 5]
# ['57177328', '편하고 이뻐요', ['착용감', '디자인'], 5]
# ['57177328', '운동화 280인데 정사이즈 주문했어요', ['사이즈'], 5]
# ['57126645', '구두를 신고 벗을 때 운동화 신고 벗듯이 편안한 게 큰 장점이구요', ['착용감', '사이즈'], 5]
# ['57126645', '걷거나 뛸때도 발 아픈 곳 없이 저의 발에 착 잘 맞습니다', ['착용감'], 5]
# ['57126645', '다음에 구두 살 때도 첫번 째로 이곳을 확인할 것 같아요', ['기타'], 5]
# ['57126507', '일터에서 신을 편한 구두를 찾다 할인해서 구매해 봤습니다', ['착용감', '가성비'], 5]
# ['57126507', '오자마자 처음 신었을 때 발이 아프지 않고 편하기 쉽지 않은데 이 구두는 편안했어요', ['착용감'], 5]
# ['57126507', '그후로 쭉 잘 신고 있구요', ['기타'], 5]
# ['57126507', '자주 사용해서 주름이 졌지만 자연스러운 주름이라 신경쓰이진 않구요', ['기타'], 5]
# ['57126507', '너무너무 편해서 구두하나 더 필', ['착용감'], 5]
# ['57124704', '기본템인 것 같아요', ['기타'], 5]
# ['57124704', '디자인도 깔끔해서 좋네요', ['디자인'], 5]
# ['57120911', '예뻐요', ['디자인'], 5]
# ['57120911', '재구매입니다', ['기타'], 5]
# ['57120911', '추천합니다', ['기타'], 5]
# ['57120911', '평소 265 신어요', ['사이즈'], 5]
# ['57118582', '디자인이 무난해요', ['디자인'], 5]
# ['57118582', '발볼이 살짝끼지만 착용했을때 가볍고 편한거같아요', ['착용감', '사이즈'], 5]
# ['57118582', '가격대비 만족합니다 ', ['가성비'], 5]
# ['57048701', '더비슈즈 처음사봤는데 이쁘고 발도 편하네요', ['착용감', '디자인'], 5]
# ['57001356', '다 좋은데 발등이 들어갈때 아파요', ['착용감', '사이즈'], 5]
# ['57001356', '업해도 될거같아요', ['사이즈'], 5]
# ['56996566', '가격대 맞는 퀄입니다 입문이나 부담 없이 신기에 적합한거 같아요', ['가성비'], 3]
# ['56996566', '끈이나 디테일이 아쉽게도 고급스럽지는 않아요', ['디자인'], 3]
# ['56996566', '발목 많이까집니다', ['착용감'], 3]
# ['56996566', '패드나 꽉 맞는 사이즈 사시는걸 추천 드려요', ['사이즈'], 3]
# ['56972619', '만족합니다', ['기타'], 5]
# ['56972619', '합리적인가격에 사서 만족합니다', ['가성비'], 5]
# ['56972619', '좋은상품 앞으로도 부탁해요', ['디자인'], 5]
# ['56912183', '나가서 신어보진않았지만 발사이즈 딱맞고 예쁘네요', ['착용감', '사이즈', '디자인'], 5]
# ['56603472', '오랫동안 장바구니에만 넣어놨다가 이제서야 구매를 하네요', ['기타'], 5]
# ['56603472', '처음이라 잘 안들어가고 딱딱하지만', ['착용감'], 5]
# ['56603464', '오랫동안 장바구니에만 넣어놨다가 이제서야 구매를 하네요', ['기타'], 5]
# ['56603464', '처음이라 잘 안들어가고 딱딱하지만', ['착용감'], 5]
# ['56603452', '오랫동안 장바구니에만 넣어놨다가 이제서야 구매를 하네요', ['기타'], 5]
# ['56603452', '처음이라 잘 안들어가고 딱딱하지만', ['착용감'], 5]
# ['56486112', '처음으로 더비슈즈 입문하는데 편하네요', ['착용감', '가성비'], 5]
# ['56486112', '재고때문에 배송이 느렷던거 빼고는', ['배송 및 포장 및 응대'], 5]
# ['56469716', '발볼 넓은편인데 맞고 착화감이 편하네여', ['착용감', '사이즈'], 5]
# ['56468767', '발볼 넓은편인데 맞고 착화감이 편하네여', ['착용감', '사이즈'], 5]
# ['56464125', '만족할 만큼 좋은 상품이에요', ['기타'], 5]
# ['56464125', '감사합니다', ['기타'], 5]
# ['56464125', '다른 신발도 사볼게요', ['기타'], 5]
# ['56464107', '만족할 만큼 좋은 상품이에요', ['기타'], 5]
# ['56464107', '감사합니다', ['기타'], 5]
# ['56464107', '다른 신발도 사볼게요', ['기타'], 5]
# ['56456810', '마이에미프로젝트 역시 편합니다 이가격대에 이런 신발 없숩니다', ['가성비'], 5]
# ['56451630', '다른 리뷰처럼 끈은 아쉽지만 가죽재질이나 착화감은 훌륭합니다 전투용으로도 만족합니다', ['착용감', '내구성 및 품질'], 5]
# ['56450888', '꽤나 가성비 좋고 싸게 신을 수 있는 가죽 로퍼에요', ['내구성 및 품질', '가성비'], 5]
# ['56427387', '아니 이 사람들 신발 잘 만드네요', ['기타'], 5]
# ['56427387', '어떤 꾼들이 만들지 모르겠지만 대단해요', ['기타'], 5]
# ['56415460', '평소 운동화 275신는데 270사이즈 잘 맞습니다', ['사이즈'], 5]
# ['56415460', '가볍고 좋아요', ['착용감'], 5]
# ['56408654', '신발이 가볍고 키높이가 마니들어가있는데도 신었을때 편해요', ['착용감', '디자인'], 5]
# ['56408654', '잘 만든듯', ['기타'], 5]
# ['56408554', '무난한 디자인이고 착화감이 좋아서 자주 신을듯', ['착용감', '디자인'], 5]
# ['56408554', '소가죽이라 오래 신겠죠', ['내구성 및 품질'], 5]
# ['56408404', '무엇보다 소가죽인데도 신었을때 편했어요', ['내구성 및 품질'], 5]
# ['56338366', '사이즈가 크네요', ['사이즈'], 4]
# ['56338366', '편하기는 편합니다', ['착용감'], 4]
# ['56338366', '한사이즈 다운해서 신으면 될꺼 같아요', ['사이즈'], 4]
# ['56298457', '편하고 좋아요', ['착용감'], 5]
# ['56298457', '가성비도 좋고 색감도 만족스러워요', ['디자인', '가성비'], 5]
# ['56238215', '저렴하레 잘샀네요', ['가성비'], 5]
# ['56238215', '정사이즈로 착화감도 괜찮습니다', ['착용감', '사이즈'], 5]
# ['56216576', '디자인이 이쁘고 가격이 착해서 좋은거 같어요', ['디자인', '가성비'], 5]
# ['56205666', '와', ['기타'], 5]
# ['56205666', '구두 신고 일하는 사람인데 스타일도 챙겨야 해서 늘 불편해도 예쁜 구두를 신었는데요', ['착용감', '디자인'], 5]
# ['56205666', '후기 믿고 사봤는데 예쁘기도 하고 지금까지 살면서 신은 구두 중 편하네요', ['착용감', '디자인'], 5]
# ['56205666', '저렴하기까지', ['착용감', '가성비'], 5]
# ['56205666', '두고두고 신으려고 하나 있는데 또 하나 더 샀습니다', ['기타'], 5]
# ['56170403', '제가 발볼이 넓은편인데 정사이즈 주문했어요', ['사이즈'], 5]
# ['56170403', '착용감도 편하고 디자인도 맘에 듭니다 이쁘네요', ['착용감', '디자인'], 5]
# ['55962429', '여자가 신어도 이쁩니다', ['디자인'], 5]
# ['55962429', '레드컬러 양말에 전체적으로 검정색 코디하니까 세련되보이고 굽이 있지만 착화감도 편합니다', ['착용감', '디자인'], 5]
# ['56117817', '사이즈 때문에 고민하다가 280 주문했는데 편하네요', ['착용감', '사이즈'], 5]
# ['56117817', '굽이 높은데 딱딱하지 않아서 오래 걸어도 편안핮니다', ['착용감', '내구성 및 품질', '디자인'], 5]
# ['56078289', '남자친구 선물 주려고 구매했는데 만족하더리구요', ['기타'], 5]
# ['56078273', '남자친구 선물 주려고 구매했는데 만족하더리구요', ['기타'], 5]
# ['56068689', '무광에 기본적인 디자인이라 어디든 잘 어울릴 듯', ['디자인'], 5]
# ['56068689', '저렴한 가격에 득템했네요', ['가성비'], 5]
# ['56068543', '가죽이 얇지만 부드럽고 촉감이 좋습니다', ['착용감', '내구성 및 품질'], 5]
# ['56068543', '바닥도 쿠션이 좋아 편합니다', ['착용감'], 5]
# ['56055393', '엄청난 세일로 구매했습니다', ['가성비'], 5]
# ['56055393', '발볼이 안 맞을까 평소 구두 사이즈가 아닌 운동화 사이즈로 구입했더니 잘 맞네요', ['사이즈'], 5]
# ['56055393', '발볼이 좁은게 아니면 운동화 정사이즈 추천입니다', ['사이즈'], 5]
# ['56055393', '가죽은 얇은 편이나 밑창이 쿠션감이 좋습니다', ['착용감', '내구성 및 품질'], 5]
# ['56052305', '기본템으로 무난하게 신기 좋아요', ['기타'], 5]
# ['56052305', '가격대비 좋습니당', ['가성비'], 5]
# ['56050286', '다른제품도 구매하려고합니다', ['기타'], 5]
# ['56050286', '좋은제품 감사합니다', ['기타'], 5]
# ['56035239', '가격이 합리적이고 사이즈가 크니 참고하시면 좋을 것 같습니다', ['사이즈', '가성비'], 5]
# ['56031259', '자주 신지는 않을거라 싼거 샀는데 괜찮네요', ['가성비'], 5]
# ['56031259', '사이즈도 운동화 신는 사이즈랑 똑같이 샀어요', ['사이즈'], 5]
# ['55965209', '신발 이뻐요', ['디자인'], 4]
# ['55965209', '편하고 크게 나온듯 실제로도 커보임', ['착용감', '사이즈'], 4]
# ['55961008', '발볼이 넓은 편인데 불편하지 않아요', ['착용감', '사이즈'], 5]
# ['55961008', '다른 구두에 비해서 무게가 가벼워서 피로도가 줄었습니다', ['착용감'], 5]
# ['55960994', '발볼이 넓은 편인데 불편하지 않아요', ['착용감', '사이즈'], 5]
# ['55960994', '다른 구두에 비해서 무게가 가벼워서 피로도가 줄었습니다', ['착용감'], 5]
# ['55959595', '세일해서 사봤는데 단정하고 깔끔해서 이쁩니다', ['디자인', '가성비'], 5]
# ['55959595', '잘 산것 같아요', ['기타'], 5]
# ['55950789', '배송도 빠른 편이고 가격대비 퀄리티도 좋습니다', ['내구성 및 품질', '가성비', '배송 및 포장 및 응대'], 5]
# ['55904141', '너무좋습니다', ['기타'], 5]
# ['55904141', '또살 의향있어요', ['기타'], 5]
# ['55904141', '핏도 좋습니다', ['디자인'], 5]
# ['55864438', '신발은 이쁘고 착화감도 편합니다 발이 커보이는 신발이예요', ['착용감', '디자인'], 4]
# ['55819695', '면접볼 때 신으려고 샀는데 편하고 좋아요', ['착용감'], 5]
# ['55815409', '사이즈가 크긴 디자인이랑 착화감은 대만족입니다', ['착용감', '사이즈', '디자인'], 5]
# ['55815409', '이런 신발을 이제 발견해서 다음에는 로퍼 도전해야겠습니다', ['기타'], 5]
# ['55766671', '마감이 세상 허술하나', ['내구성 및 품질'], 3]
# ['55766671', '멀리서 보기엔 괜찮음 가격대에 맞는 퀄리티로 전투용에 적합', ['내구성 및 품질', '가성비'], 3]
# ['55766671', '하루정도 신으면 모양이 잡힘', ['디자인'], 3]
# ['55766534', '처음 왔을때는 세상 이상한 모양이었는데 하루정도 신고다니면 라인이 잡힘', ['디자인'], 3]
# ['55766534', '제품 마감이 아쉬움', ['내구성 및 품질'], 3]
# ['55766534', '자세히 안보면 전투용으로 괜찮음', ['기타'], 3]
# ['55738901', '265 였음', ['사이즈'], 5]
# ['55738901', '편하게 잘맞았을텐데 저에겐 작지만 얇은 면양말 신으면 나름 잘 신을수 있어요', ['착용감', '사이즈'], 5]
# ['55738097', '좋습니다', ['기타'], 5]
# ['55738097', '굿굿 배송이 빠르고 상품이 마음에들어요', ['배송 및 포장 및 응대'], 5]
# ['55737662', '좋습니다', ['기타'], 5]
# ['55737662', '굿굿 배송이 빠르고 상품이 마음에들어요', ['배송 및 포장 및 응대'], 5]
# ['55737649', '좋습니다', ['기타'], 5]
# ['55737649', '굿굿 배송이 빠르고 상품이 마음에들어요', ['배송 및 포장 및 응대'], 5]
# ['55707913', '배송 빠르게 잘 왔습니다', ['배송 및 포장 및 응대'], 5]
# ['55707913', '가성비 좋은 제품인거 같아요', ['가성비'], 5]
# ['55682174', '요번 친척형 결혼식겸 평소에 신고다닐려고 입문용으로 샀습니다', ['가성비'], 5]
# ['55682174', '발285290인데도 딱맞아요', ['착용감', '사이즈'], 5]
# ['55675567', '많이 마음에 들어요', ['기타'], 5]
# ['55675567', '좋은 제품 감사합니다', ['기타'], 5]
# ['55671598', '보통 운동화 265신다보니 260 시켰는데 끼더라고요', ['사이즈'], 5]
# ['55671598', '깔창이 높아서 그렇지 일반깔창 하면 개꿀이요', ['기타'], 5]
# ['55668314', '가격 저렴하게 잘산거같아요', ['가성비'], 5]
# ['55668314', '착화감은 제대로 신어봐야 알거같아요', ['착용감'], 5]
# ['55668283', '가격 저렴하게 잘산거같아요', ['가성비'], 5]
# ['55668283', '착화감은 제대로 신어봐야 알거같아요', ['착용감'], 5]
# ['55638632', '첫 더비슈즈 엄청만족합니다 가격도 싸고 입문용 괜찮은거같아요', ['가성비'], 5]
# ['55617628', '평소에 신던 구두와 다르게 발바닥 쿠션이 상당해서 발에 피로가 많이 줄어들 것 같습니다', ['착용감'], 5]
# ['55617609', '평소에 신던 구두와 다르게 발바닥 쿠션이 상당해서 발에 피로가 많이 줄어들 것 같습니다', ['착용감'], 5]
# ['55606299', '스타일링하기 무난하고 가죽질감도 좋고 신기 편해요', ['착용감', '내구성 및 품질', '디자인'], 5]
# ['55606285', '스타일링하기 무난하고 가죽질감도 좋고 신기 편해요', ['착용감', '내구성 및 품질', '디자인'], 5]
# ['55603610', '발볼이넒어서 285290신는데 잘맞고 뒤꿈치 살짝뜨는데 꽉끈하먼 괜찮아집니다', ['사이즈', '디자인'], 5]
# ['55603610', '오른쪽 발볼 끼는거같은디 신다보면 늘어나니 계속신을려규요', ['착용감', '사이즈', '내구성 및 품질'], 5]
# ['55580212', '좋아요', ['기타'], 5]
# ['55580212', '원하던 디자인이라 마음에 들고 사이즈도 잘 맞아요', ['사이즈', '디자인'], 5]
# ['55560240', '완전무광도 아니고 은은하니 예뻐요', ['디자인'], 5]
# ['55560240', '싼만큼 가죽이 얇은 감은 있어요', ['내구성 및 품질', '가성비'], 5]
# ['55560135', '가성비 미쳤네요', ['가성비'], 5]
# ['55560135', '이가격에 이런 품질은 놀랍네요', ['내구성 및 품질', '가성비'], 5]
# ['55525182', '이게 구둔지 단화지 모를만큼 편안합니다', ['착용감'], 3]
# ['55525182', '닥터마틴류는 처음에 길들이는데 고생하는데 그런게 1도 없습니다', ['착용감'], 3]
# ['55525182', '바로 달리기 각', ['기타'], 3]
# ['55525182', '바닥이 높아서 키높이 효과도 상당한것도 장점입니다', ['디자인'], 3]
# ['55525182', '단 깔창 바닥부에 노란색 로고가 있는데', ['디자인'], 3]
# ['55525182', '그게 앉을때나 다리꼬을깨 발을 들면 발바닥에 보이는게', ['디자인'], 3]
# ['55524916', '배송빠르고 좋았어요', ['배송 및 포장 및 응대'], 5]
# ['55524916', '재질도 쫀쫀하니 다음에또구매할생각있습니다', ['내구성 및 품질'], 5]
# ['55523428', '가격대비 가성비 좋은 신발인굿 같습다 잘 입을게요', ['가성비'], 3]
# ['55492565', '몇년만에 신발 밑창이 뜯어지고 뒷꿈치가 헤져서 새로 구입합니다', ['디자인'], 5]
# ['55492565', '일하는데 발이 편해서 자주 신어요', ['착용감'], 5]
# ['55492565', '다음에 또 구매할게요', ['기타'], 5]
# ['55490250', '입문하기도 좋고 디자인도 괜찮고 전투용으로 추천합니다', ['디자인', '가성비'], 5]
# ['55471429', '싼맛으로 신는즁 가송비 좋음 싼티 않나진 않음 좋음', ['가성비'], 5]
# ['55439802', '가성비제품이라 걸을때 불편하고 뒤꿈치 피나기 쉬움', ['착용감', '디자인', '가성비'], 3]
# ['55391069', '초반에 신으면 발이 아프고 불편하기는 한데 적응되면 편하게 느껴집니다', ['착용감'], 5]
# ['55391069', '디자인도 예쁘고 좋습니다', ['디자인'], 5]
# ['55386929', '가성비 굉장히 좋아요', ['가성비'], 5]
# ['55386929', '볼이 작긴한데 디자인 가죽 아웃솔 다 가격대비 대만족입니다', ['사이즈', '내구성 및 품질', '디자인', '가성비'], 5]
# ['55386919', '가성비 굉장히 좋아요', ['가성비'], 5]
# ['55386919', '볼이 작긴한데 디자인 가죽 아웃솔 다 가격대비 대만족입니다', ['사이즈', '내구성 및 품질', '디자인', '가성비'], 5]
# ['55334139', '배송 빠르구여', ['배송 및 포장 및 응대'], 5]
# ['55334139', '아쉬운 건 배송 왔을 때 신발 표면에 껍질이 있어 싼마이 느낌이 쫌 났네여', ['착용감', '내구성 및 품질', '가성비', '배송 및 포장 및 응대'], 5]
# ['55334130', '배송 빠르구여', ['배송 및 포장 및 응대'], 5]
# ['55334130', '아쉬운 건 배송 왔을 때 신발 표면에 껍질이 있어 싼마이 느낌이 쫌 났네여', ['착용감', '내구성 및 품질', '가성비', '배송 및 포장 및 응대'], 5]
# ['55324625', '배송이 빠르고 키높이가 높아서 만족스럽습니다', ['디자인', '배송 및 포장 및 응대'], 5]
# ['55322712', '할인해서 좋은 가격에 구매했습니다', ['가성비'], 5]
# ['55322712', '가격대비 만족합니다', ['가성비'], 5]
# ['55322697', '할인해서 좋은 가격에 구매했습니다', ['가성비'], 5]
# ['55322697', '가격대비 만족합니다', ['가성비'], 5]
# ['55154580', '발 실측 260mm라 운동화 270 신는데 운동화 시이즈로 사면 된다고 해서 270 샀는데 사이즈 맞네요', ['사이즈'], 5]
# ['55097657', '가성비가 좋고 가볍고 편안해요', ['착용감', '가성비'], 5]
# ['55097657', '키높이도 잇는거 같고 좋네요', ['디자인'], 5]
# ['55016046', '소개팅때 신고 나가려고 샀는데 괜찮았음', ['기타'], 5]
# ['55016046', '성공적이었음', ['기타'], 5]
# ['54896946', '가격대비 질이 좋고 예쁩니다', ['내구성 및 품질', '디자인', '가성비'], 5]
# ['54896946', '열심히 신고 다니다가 망가지면 또 살거에요', ['기타'], 5]
# ['54895659', '이 브랜드의 신발이 편해서 몇번사서쓰고있는데 이거는 불편해요', ['착용감'], 3]
# ['54537414', '금액 대비 디자인은 예쁘고 착화감도 하루 이틀 신으면 편합니다', ['착용감', '디자인'], 5]
# ['54537414', '데일리로 신기 좋아요', ['기타'], 5]
# ['54526329', '265 였음', ['사이즈'], 5]
# ['54526329', '편하게 잘맞았을텐데 저에겐 작지만 얇은 면양말 신으면 나름 잘 신을수 있어요', ['착용감', '사이즈'], 5]
# ['54509037', '필요해서 구매했습니다', ['기타'], 5]
# ['54509037', '맘에들어요', ['기타'], 5]
# ['54509037', '감사합니다', ['기타'], 5]
# ['54422903', '입문용으로 하나 구매했습니다', ['가성비'], 5]
# ['54422903', '무난하게 신을 수 있을 것 같아요', ['기타'], 5]
# ['54167005', '사이즈도 적당하고 신었을때 착용감도 좋습니다', ['착용감', '사이즈'], 5]
# ['54135316', '광이 있는 편이구요 정사이즈 선택하셔도 좋을듯 합니다', ['사이즈'], 5]
# ['54135316', '무난하게 신기 좋을듯 하네요', ['기타'], 5]
# ['54125351', '가성비가 미쳤어요', ['가성비'], 5]
# ['54125351', '더비 슈즈는 다 불편하다고 생각했는데 처음부터 신고 다닐만 해서 좋았습니다', ['착용감'], 5]
# ['54125351', '제 사이즈는 250은 꽉 맞고 260은 남는 정도입니다', ['사이즈'], 5]
# ['54113296', '데일리로 신기에 예뻐용 자주 신을 것 같습니다', ['디자인'], 5]
# ['54113284', '착용감도 좋고 편하게 신을 수 있을 것 같아요', ['착용감'], 5]
# ['54113284', '예쁩니당', ['디자인'], 5]
# ['54113273', '발이 편해서 좋았어요', ['착용감'], 5]
# ['54113273', '데일리로 신기에도 좋네요', ['기타'], 5]
# ['54109361', '얄쌍해서 덜 캐주얼한 느낌이 있지만 기본 더비로서는 굿입니다', ['착용감', '디자인'], 5]
# ['54109352', '얄쌍해서 덜 캐주얼한 느낌이 있지만 기본 더비로서는 굿입니다', ['착용감', '디자인'], 5]
# ['54088788', '사이즈 정사이즈이고 이쁩니다', ['사이즈', '디자인'], 5]
# ['54088788', '새신발임에도 뒷꿈치가 까지서나 하는 불편한거 없이 잘 신고 있습니다', ['착용감', '디자인'], 5]
# ['53934088', '가격때문에 기대 안 하고 샀는데 가격대비 잘 나온 상품인거 같아요', ['가성비'], 4]
# ['53934088', '몇 번 신을 생각으로 샀는데 많이 신을꺼 같아요', ['기타'], 4]
# ['53925165', '광이 있는 편이고 굽이 어느 정도 높은 제품이라 키높이 구두로도 손색이 없습니다', ['디자인'], 5]
# ['53925165', '가성비 더비 슈즈를 찾고 계시면 추천드립니다', ['가성비'], 5]
# ['53925131', '가성비 더비 슈즈를 찾고 계신다면 추천드립니다 가격대비 색감 및 착용감이 좋아서 다른 색상도 사고 싶은 마음이예요', ['착용감', '디자인', '가성비'], 5]
# ['53699059', '최고에요', ['기타'], 5]
# ['53699059', '유명하고 스태디샐러인 제품도 나름 비싸게 주고사서 신어봤지만 무겁고 발아작나고 도대체 왜유명한거지', ['착용감', '사이즈', '가성비'], 5]
# ['53699059', '왜 좋고 스태디샐러인거지', ['기타'], 5]
# ['53699059', '했었는데 여기 제품 두번째인데 가격대비 싼티도 안나고 데일리로 신기 완전좋고 새상품 정사이즈로 신어도 발 하나도 안아프고 완전편하고 좋아요', ['착용감', '사이즈', '가성비'], 5]
# ['53699059', '두제품', ['기타'], 5]
# ['53681526', '가격 적당해서 무난하게 막 신기 좋아요', ['가성비'], 5]
# ['53681526', '발 편해요', ['착용감'], 5]
# ['53681504', '가격 적당해서 무난하게 막 신기 좋아요', ['가성비'], 5]
# ['53681504', '발 편해요', ['착용감'], 5]
# ['53665440', '배송 빠르고 신발이 막 편하지는 않은데 무난하게 신기에 좋아요', ['착용감', '배송 및 포장 및 응대'], 5]
# ['53561791', '배송도 배르고 시계도 마음에 드네요', ['배송 및 포장 및 응대'], 5]
# ['53561791', '오랫동안 이쁘그게 착용하겠습니다', ['착용감', '디자인'], 5]
# ['53561791', '다 갑사합니다', ['기타'], 5]
# ['53490475', '예쁘고 발에 잘 맞아서 편합니다', ['디자인'], 5]
# ['53490475', '잘 사용하겠습니다', ['기타'], 5]
# ['53351548', '착화감이 편해서 계속 찾게되는 신발 회사에 계속 이것만 신고가게돼요', ['착용감'], 5]
# ['53348085', '평발이라 착화감에 예민한데 이 신발은 푹신해서 전혀 부담없어요', ['착용감'], 5]
# ['53348085', '오히려 더 신고다니고 싶더라구요', ['기타'], 5]
# ['53348085', '신발 디자인도 무난해서 저처럼 패션모르는 사람은 이 신발을 우선으로 넓혀가는게 좋을거 같습니다', ['디자인'], 5]
# ['53317137', '가죽 재질도 괜찮고 발볼이 넓은 사란한테도 잘 맞음', ['사이즈', '내구성 및 품질'], 4]
# ['53311302', '입문용으로 강추 그립니다', ['가성비'], 5]
# ['53311302', '발 편해요', ['착용감'], 5]
# ['53311302', '강추', ['기타'], 5]
# ['53231544', '컴포트하고 디자인도 예쁘네요', ['디자인'], 5]
# ['53231544', '편하게 여기저기신기 좋은거같아요', ['착용감'], 5]
# ['53185648', '착화감이 가죽 구두임에도 불구하고 편했어요', ['착용감', '내구성 및 품질'], 5]
# ['53185648', '키높이도 적당히 되고 좋아요', ['디자인'], 5]
# ['53185648', '', ['기타'], 5]
# ['53033092', '굽도 높고 운동화처럼 편해요', ['착용감', '디자인'], 5]
# ['53033092', '휘뚜루마뚜루 신기 좋은것같습니다', ['기타'], 5]
# ['52941902', '할인과 쿠폰으로 싼 가격에 잘 샀습니다', ['가성비'], 5]
# ['52941902', '이 가격에 이 퀄리티면 나중에 또 구매할거 같아요', ['내구성 및 품질', '가성비'], 5]
# ['52834286', '고민하고 주문을 했는데 사진처럼 괜찮네요', ['기타'], 5]
# ['52834286', '가죽이라하지만 레자같아 보입니다', ['내구성 및 품질'], 5]
# ['52834286', '저렴하니깐 그만큼 신을수 있을거 같아요', ['가성비'], 5]
# ['52502630', '발볼 적당하고 착화감은 기대이상 좋아요', ['착용감', '사이즈'], 5]
# ['52502630', '유광이라 참고하시고 더비슈즈는', ['기타'], 5]
# ['52502630', '첨인데 입문용으로는 부담없이 잘 신고다닐거같습니다', ['가성비'], 5]
# ['52502242', '키높이같은거는 잘안하고 다니는 터라 잘몰랐는데 이거신고 4cm위의 공기가 이렇게 상쾌하단걸 알게되었습니다', ['디자인'], 5]
# ['52502242', '폭신하니 편하고 발볼도 딱맞고 조금더 뭉툭하길 바랬지만 이것도 매력있게 이쁘네요', ['착용감', '사이즈', '디자인'], 5]
# ['52288713', '배송도 빠르고 신발도 이뻐요', ['디자인', '배송 및 포장 및 응대'], 5]
# ['52288713', '편하게 신을 수 있어요', ['착용감'], 5]
# ['51871492', '발이 편하고 키높이가 많이되서 좋은거같아요', ['착용감', '디자인'], 5]
# ['51618588', '일반 구두와 다르게 발바닥이 편안하여 출퇴근용으로 자주 신고 있어요 ', ['착용감'], 5]
# ['51570988', '첼시부츠 처음 신어볼려고 고르다가 샀는데 이쁘고 사이즈도 잘 맞는거 같습니다', ['사이즈', '디자인'], 5]
# ['51483100', '이쁘고 뻘리왔네요', ['디자인'], 5]
# ['51483100', '신을때마다 만족하고있습니다', ['기타'], 5]
# ['51234244', '척화감이 좋아요', ['기타'], 5]
# ['51234244', '발 아플 걱정은 없는거 같습니다 광이 많이 나는게 제 기준에서는 아쉽네요', ['착용감'], 5]
# ['51068812', '추가로 사이즈 255 신는데 260 신으니까 편하게 맞아요', ['착용감', '사이즈'], 5]
# ['51068812', '고민하지 마시고 255 신는분들은 260 가시면 될것 같아요', ['사이즈'], 5]
# ['51013664', '이뻐요', ['디자인'], 5]
# ['51013664', '착화감 나쁘지 않고 발 뒤꿈치 안까져서 좋아요', ['착용감', '디자인'], 5]
# ['51013809', '이뻐요', ['디자인'], 5]
# ['51013809', '착화감 나쁘지 않고 발 뒤꿈치 안까져서 좋아요', ['착용감', '디자인'], 5]
# ['50993886', '적당하고 이쁨 이 가격대엔 만족 저번에 산 거는 뒷꿈치 다까졌는데 그건 덜항', ['착용감', '디자인', '가성비'], 5]
# ['50842048', '가격이나 키높이 부분은 좋은데 오룬쪽 발가락이 아파요', ['착용감', '디자인', '가성비'], 5]
# ['50775191', '전에 샀던 신발 착화감이 좋아서 믿고 구매했습니다', ['착용감'], 5]
# ['50775191', '역시 좋네요', ['기타'], 5]
# ['50775184', '전에 샀던 신발 착화감이 좋아서 믿고 구매했습니다', ['착용감'], 5]
# ['50775184', '역시 좋네요', ['기타'], 5]
# ['50737607', '착용감 적당해서 좋았고 디자인 색감 모두 이쁩니다', ['착용감', '디자인'], 5]
# ['50734857', '전에 샀던 신발 착화감이 좋아서 믿고 구매했습니다', ['착용감'], 5]
# ['50734857', '역시 좋네요', ['기타'], 5]
# ['50300302', '구두치고 편안하게 잘맞아요 ', ['착용감'], 4]
# ['50300302', ' 높이도 적당한 것 같습니다', ['디자인'], 4]
# ['50300284', '구두치고 편안하게 잘맞아요 ', ['착용감'], 5]
# ['50300284', ' 높이도 적당한 것 같습니다', ['디자인'], 5]
# ['50240200', '가죽이 벗고신기 편하네요', ['착용감', '내구성 및 품질'], 5]
# ['50240200', '한달 넘게 자주 신었는데 구겨짐이 심하진않아요', ['기타'], 5]
# ['50240200', '잘신겠습니다', ['기타'], 5]
# ['50221617', '볼드해서 어디든 어울려요', ['디자인'], 5]
# ['50221617', '자주 신을것 같아요', ['기타'], 5]
# ['50221617', '뒤꿈치 까지긴해도 좋아요', ['착용감', '디자인'], 5]
# ['50073939', '제 발사이즈가 250인데 딱맞게 신으면 안될꺼같은 생각도 드네요', ['착용감', '사이즈'], 4]
# ['49940397', '구두는 발이 아파서 다른신발 찾아보다가 발견했는데 발이 확실히 편해요', ['착용감'], 5]
# ['49791590', '발등이 작아요', ['사이즈'], 4]
# ['49791590', '오래신으면 늘어날것같긴해요', ['내구성 및 품질'], 4]
# ['49791590', '굽이 있어요', ['디자인'], 4]
# ['49753696', '원래 신발 280 신고 280시켰는데 발등이 작아요', ['사이즈'], 4]
# ['49753696', '계속신어서 늘리면 늘릴수있을것같아요', ['기타'], 4]
# ['49691001', '평소 운동화 285290 신고 발볼 넓은 편인데 290주문햇습니다', ['사이즈'], 5]
# ['49691001', '사이즈 편하게 신 좋아요', ['착용감', '사이즈'], 5]
# ['49516884', '잘 산거 같아요 두음에도 다른걸로 도전해볼게요', ['기타'], 5]
# ['49516884', '많이 파세여', ['기타'], 5]
# ['49422172', '무난하니좋습니다', ['기타'], 4]
# ['49422172', '데일리로 신기좋아요', ['기타'], 4]
# ['49422172', '편하구', ['착용감'], 4]
# ['49094294', '더비구두 처음샀는대', ['기타'], 5]
# ['49094294', '편합니다', ['기타'], 5]
# ['49094294', '이가격에 이렇게 편할수없어요', ['가성비'], 5]
# ['48780094', '예쁘고 좋네요', ['디자인'], 5]
# ['48780094', '사이즈도 적당합니다', ['사이즈'], 5]
# ['48780094', '마음에 드네요', ['기타'], 5]
# ['48667128', '포장은 쫌 반품했던거온것같은 느낌이네요', ['착용감', '배송 및 포장 및 응대'], 2]
# ['48667128', '구두치곤 편한데 박스도 너무헐어있고 받는입장에서 기분이썩', ['착용감', '배송 및 포장 및 응대'], 2]
# ['48633066', '쉐잎이 좋아서 샀습니다', ['디자인'], 5]
# ['48633066', '좋은 더비에요', ['기타'], 5]
# ['48633066', '어디에나 어울려요', ['디자인'], 5]
# ['48514625', '가성비 좋으면서 이쁘게 신기 좋은 구두입니다', ['디자인', '가성비'], 5]
# ['48514625', '추천드려요', ['기타'], 5]
# ['48368519', '너무너무 좋네요', ['기타'], 5]
# ['48368519', '또 사고싶어요', ['기타'], 5]
# ['48368519', '포장도 꼼꼼해요', ['배송 및 포장 및 응대'], 5]
# ['48103965', '발아플까봐 걱정되서 평점 좋은걸로 샀는데 편하고 이뻐요', ['착용감', '디자인'], 5]
# ['48103965', '키높이 효과도 있네요', ['디자인'], 5]
# ['48103958', '발아플까봐 걱정되서 평점 좋은걸로 샀는데 편하고 이뻐요', ['착용감', '디자인'], 5]
# ['48103958', '키높이 효과도 있네요', ['디자인'], 5]
# ['48103951', '발아플까봐 걱정되서 평점 좋은걸로 샀는데 편하고 이뻐요', ['착용감', '디자인'], 5]
# ['48103951', '키높이 효과도 있네요', ['디자인'], 5]
# ['48027065', '전에 로퍼 260으로 구매해서 사이즈 선택에 불편함은 없었네요', ['착용감', '사이즈'], 5]
# ['48027065', '키높이 되고 좋아요', ['디자인'], 5]
# ['47956712', '푹신푹신하고 실제로 신어보니 사진보다 더 예뻐요', ['착용감', '디자인'], 5]
# ['47880575', '고민을 많이 해서 샀는데 만족스럽네요', ['기타'], 5]
# ['47880575', '사길 잘했어요', ['기타'], 5]
# ['47798243', '배송도 빠르고 전반적으로 편한 느낌입니다', ['착용감', '배송 및 포장 및 응대'], 4]
# ['47798243', '새 구두에 적응을 잘 해 보겠습니다', ['기타'], 4]
# ['47785381', '착화감 좋고 발이 안 아파서 좋아요', ['착용감'], 5]
# ['47785381', '큰 치수로 샀는데도 안 벗겨지고 편안합니다', ['착용감', '사이즈'], 5]
# ['47515204', '265 운동화 착용합니다', ['착용감', '사이즈'], 5]
# ['47515204', '구두는 260 신어서 주문했는데 밑창이 두꺼워서 그런지 맞는 느낌입니다', ['착용감', '사이즈'], 5]
# ['47515204', '불편하지만 신다보면 늘어 날 것 같아서 신을 것 같아요', ['착용감', '내구성 및 품질'], 5]
# ['47383923', '할인할 때 사서 잘 신고있습니다', ['가성비'], 5]
# ['47383923', '좋아요', ['기타'], 5]
# ['47383923', '크게 나옴', ['사이즈'], 5]
# ['47343747', '착화감이 미쳤습니다', ['착용감'], 5]
# ['47343747', '발 편해야 신는데 얘는 뛰어도 괜찮을 정도 디자인도 무난하게 예뻐서 더 좋아요', ['착용감', '디자인'], 5]
# ['47050120', '비오는 날 신고 다니기 좋아요', ['기타'], 5]
# ['47050120', '출근은 해야하는데 등산화가 필요하다 이럴 때 좋어요', ['기타'], 5]
# ['46700823', '선물로 드렸는데 발볼 넓고 편하다고 합니다', ['착용감', '사이즈'], 5]
# ['46700823', '60대 어르신에게 선물했는데', ['기타'], 5]
# ['46593086', '밑창 이슈만 없으면 참 좋은 신발인데 재구매만 몇 번째', ['기타'], 5]
# ['46269440', '가격대비 맘에듭니다 발은 어쩔수없이 아픕니다', ['가성비'], 5]
# ['46025700', '할인할때 삿는데 이쁘네요', ['디자인', '가성비'], 4]
# ['46025700', '입문용으로 좋습니다', ['가성비'], 4]
# ['45950729', '할인할 때 얼른 삿습니다', ['가성비'], 5]
# ['45950729', '맘에 드네여', ['기타'], 5]
# ['45950729', '리얼가죽인데', ['내구성 및 품질'], 5]
# ['45844152', '항상 여기서 로퍼 사는데 더비도 여기가 제일인 거 같아요', ['기타'], 5]
# ['45844152', '끈 넣는 부분 마감이 부실한 거 같지만 끈 묶으면 어차피 너도나도 안보이는 부분이니까요', ['내구성 및 품질'], 5]
# ['45844152', '뭐', ['기타'], 5]
# ['45752348', '더비슈즈는 처음인데 입문용으로 적당한 재품인거같아요', ['가성비'], 5]
# ['45534948', '최고의 구두', ['기타'], 5]
# ['45534948', '남자라면 하나쯤 갖고 있어야하는 구두', ['기타'], 5]
# ['45534948', '제가 발이 255라 50살까60살까 고민했다가', ['사이즈'], 5]
# ['45527006', '남자라면 구두 하나쯤은 필수', ['기타'], 5]
# ['45527006', '무조건 사세요', ['기타'], 5]
# ['45527006', '', ['기타'], 5]
# ['45307649', '불편하지않고 키높이가 많이되수 좋네요', ['착용감', '디자인'], 5]
# ['45307649', '데일리로 신기도 조아요', ['기타'], 5]
# ['45281788', '키높이도 적당하고 무엇보다 편한거같아서 좋네요', ['착용감', '디자인'], 5]
# ['45266100', '박스가 다 구겨져서 왔네요', ['배송 및 포장 및 응대'], 5]
# ['45266100', '포장이 아쉽습니다', ['배송 및 포장 및 응대'], 5]
# ['45266100', '이쁘긴합니다', ['디자인'], 5]
# ['45266089', '박스가 다 구겨져서 왔네요', ['배송 및 포장 및 응대'], 5]
# ['45266089', '포장이 아쉽습니다', ['배송 및 포장 및 응대'], 5]
# ['45266089', '이쁘긴합니다', ['디자인'], 5]
# ['45264913', '가격에 비해서 질이랑 전체적으로 나쁘지 않은 거 같은데용', ['내구성 및 품질', '가성비'], 5]
# ['45264913', '사이즈도 발볼이 있는 편인데도 괜찮아요', ['사이즈'], 5]
# ['45264886', '가격에 비해서 질이랑 전체적으로 나쁘지 않은 거 같은데용', ['내구성 및 품질', '가성비'], 5]
# ['45264886', '사이즈도 발볼이 있는 편인데도 괜찮아요', ['사이즈'], 5]
# ['45242344', '안창 높이가 어마어마하네요', ['디자인'], 4]
# ['45242344', '끼고 신으면 불편한데 빼고 신으니까 편해요', ['착용감', '사이즈'], 4]
# ['45242344', '낮은 안창도 팔았으면 좋겠어요', ['기타'], 4]
# ['45242312', '안창 높이가 어마어마하네요', ['디자인'], 4]
# ['45242312', '끼고 신으면 불편한데 빼고 신으니까 편해요', ['착용감', '사이즈'], 4]
# ['45242312', '낮은 안창도 팔았으면 좋겠어요', ['기타'], 4]
# ['45211519', '이쁘고 좋은거같은데 빨리 걸으면 벗겨질거같음', ['착용감', '사이즈', '내구성 및 품질', '디자인'], 5]
# ['45027890', '사람마다 발 크기가 달라서 정확하지는 않지만 평소 270 신는데 정사이즈로 가셔도 될거 같습니다', ['사이즈', '디자인'], 5]
# ['45027890', '크게 나왔다는 얘기가 많아 1사이즈 다운했는데 끼네요', ['사이즈'], 5]
# ['44699428', '가성비 더비슈즈의 정석 착화감도 준수하고 전투용으로 합격', ['착용감', '가성비'], 5]
# ['44671379', '착화감이 좋아 벌써 세 번째 구매하고 있는데 밑창이 금방 갈라지는 이슈가 있어 아쉽습니다', ['착용감', '내구성 및 품질'], 5]
# ['44190429', '착용감도 좋고 디자인도 좋고 배송도 빨라요', ['착용감', '디자인', '배송 및 포장 및 응대'], 5]
# ['44044270', '무난하고 편하게 신을 수 있어요', ['착용감'], 5]
# ['44044270', '아무래도 비싼 더비슈즈보다는 부족할 수 있지만 입문자들은 이런거 신어보는 것도 좋을 것 같습니다', ['가성비'], 5]
# ['44037119', '배송빠르고 가격 적당하고 좋아요', ['가성비', '배송 및 포장 및 응대'], 4]
# ['44037119', '사이즈가 5단위면 좋았을껀데 크네요', ['사이즈'], 4]
# ['43978084', '간편히 무난하게 신을수있어요', ['기타'], 4]
# ['43978084', '사이즈는 정사이즈요', ['사이즈'], 4]
# ['43909559', '잇츠더 굿잡맨 입니다 구두 매니 안좋아하는 휴먼이지만 잇츠더 착화감 굿잡맨 사이즈 굿잡맨 생긴거 굿잡맨맨이', ['착용감', '사이즈'], 5]
# ['43829634', '이뻐서 놀랐습니다', ['디자인'], 5]
# ['43829634', '행사같은곳에 신고 가면 좋을것 같습니다', ['기타'], 5]
# ['43709187', '뽀죡하지도 둥글지 않은 중간의 찾던 로퍼라 마음에 듭니다', ['기타'], 5]
# ['43635192', '발 볼도 적당하고 길이도 좋고 좋습니다', ['사이즈'], 5]
# ['43635192', '굽도 높아서 키높이 좋아용', ['디자인'], 5]
# ['43468682', '더비슈즈 고민하다 이걸로 구입 했는데 생각보다', ['기타'], 5]
# ['43468682', '편하고 좋습니다', ['착용감'], 5]
# ['43396886', '이뻐요', ['디자인'], 5]
# ['43396886', '정장룩 캐주얼정장 데이트 등등 다 잘 어울려요', ['디자인'], 5]
# ['43343077', '무난무난하고 전투용으로 신기 좋습니다', ['기타'], 5]
# ['43343077', '발도 별로 안아파요', ['착용감'], 5]
# ['43343056', '무난무난하고 전투용으로 신기 좋습니다', ['기타'], 5]
# ['43343056', '발도 별로 안아파요', ['착용감'], 5]
# ['43260812', '별기대없이 구매했는데 만족스럽니다', ['기타'], 5]
# ['43260812', '데일리하게 자주 신고 다녀요', ['기타'], 5]
# ['43260812', '발도 안아파요', ['착용감'], 5]
# ['43260201', '기대없이 산건데 신고 다니기도 편하고 어디에나 어울려요', ['착용감', '디자인'], 5]
# ['43260201', '가성비좋아요', ['가성비'], 5]
# ['43218202', '구두가 필요했는데 잘 산것 같아요', ['기타'], 5]
# ['43218202', '잘 신겠습니다', ['기타'], 5]
# ['43200913', '편안하게 잘 입고 다니기 좋은 아이템 같습니다아', ['착용감'], 5]
# ['43147628', '구두가 이렇게 편할 줄은 몰랐어요', ['기타'], 5]
# ['43147628', '운동화처럼 신고다님', ['기타'], 5]
# ['43121322', '데님 슬랙스 치노 다 어울리는 것 같아요', ['디자인'], 5]
# ['43121322', '편해서 자주 신어요', ['착용감'], 5]
# ['43107184', '한치수만 크게신으면 딱맞을거같네요', ['착용감', '사이즈'], 5]
# ['43107184', '푹신하고좋아요', ['착용감'], 5]
# ['43081117', '굽도 적당히 있고 푹신해서 자주신고있어요', ['착용감', '디자인'], 5]
# ['43081117', '추천합니다', ['기타'], 5]
# ['43041771', '신었을때 편합니다', ['기타'], 5]
# ['43041771', '다른 구두보다 발이 덜 아플 것 같아요', ['착용감'], 5]
# ['43041760', '신었을때 편합니다', ['기타'], 5]
# ['43041760', '다른 구두보다 발이 덜 아플 것 같아요', ['착용감'], 5]
# ['43036875', '착용감 배송 기간 디자인 색상 모두 만족합니다', ['착용감', '디자인', '배송 및 포장 및 응대'], 5]
# ['43036875', '추천합니다', ['기타'], 5]
# ['43036840', '신발 디자인 착용감도 좋아요', ['착용감', '디자인'], 5]
# ['43036840', '배송도 빨라서 추천해요', ['배송 및 포장 및 응대'], 5]
# ['43012528', '이정도 가격에 이정도 퀄리티면 괜찮네요 싸게 잘샀어요', ['내구성 및 품질', '가성비'], 5]
# ['43000737', '가성비 더비슈즈 찾으시면 추천해요', ['가성비'], 5]
# ['43000737', '불편하진 않아요', ['착용감'], 5]
# ['42993241', '신발 앞 쉐입이 둥글게 되어있어서 와이드 슬렉스와도 잘 어울립니다', ['디자인'], 5]
# ['42993241', '입문용으로 추천드립니다', ['가성비'], 5]
# ['42799174', '키야 입문자입니다', ['가성비'], 5]
# ['42799174', '당장 구매하십쇼', ['기타'], 5]
# ['42799174', '세일가에 샀는데 잘샀다고 생각듭니다', ['가성비'], 5]
# ['42827208', '괜찮습니다', ['기타'], 5]
# ['42827208', '출근할 때 거의 매일 신고있습니다', ['기타'], 5]
# ['42799136', '입문자입니다', ['가성비'], 5]
# ['42799136', '첼시 다음으로 도전하는 것인데 받아보고 나니 괜찮네요', ['기타'], 5]
# ['42766066', '입문으로 샀는데 이뻐요', ['디자인', '가성비'], 5]
# ['42766066', '무광이라 마음에 듭니다', ['기타'], 5]
# ['42766056', '입문으로 샀는데 이뻐요', ['디자인', '가성비'], 5]
# ['42766056', '무광이라 마음에 듭니다', ['기타'], 5]
# ['42703577', '가죽이 약해서 오래 못신을수도 있을것 같지만 입문용으로는 강추입니다', ['내구성 및 품질', '가성비'], 5]
# ['42691946', '저렴하게 구매했습니다', ['가성비'], 4]
# ['42691946', '잘 신고다닐게요 감사해요', ['기타'], 4]
# ['42691910', '몇번씩 재구매하는 제품입니다', ['기타'], 4]
# ['42691910', '저렴하게 잘 구매했어요', ['가성비'], 4]
# ['42687559', '착화감이 편하고 좋아요', ['착용감'], 5]
# ['42687559', '다른 구두 종류보다 발이 덜 아파요', ['착용감'], 5]
# ['42640987', '입문용 구두인데 편해서 놀랐습니다', ['착용감', '가성비'], 5]
# ['42640987', '좋아용', ['기타'], 5]
# ['42637701', '퀄리티 좋아요', ['내구성 및 품질'], 5]
# ['42637701', '저렴한 가격에 신기좋아요', ['가성비'], 5]
# ['42633007', '신발이 가볍고 편안해요 험허게 신는다면 오래 못신을거같아요', ['착용감', '내구성 및 품질'], 5]
# ['42603422', '아주마음에 듭니다 가성비 최고구요', ['가성비'], 5]
# ['42603422', '고급스러워 보여서 더 좋습니다', ['디자인'], 5]
# ['42603404', '아주마음에 듭니다 가성비 최고구요', ['가성비'], 5]
# ['42603404', '고급스러워 보여서 더 좋습니다', ['디자인'], 5]
# ['42603368', '아주마음에 듭니다 가성비 최고구요', ['가성비'], 5]
# ['42603368', '고급스러워 보여서 더 좋습니다', ['디자인'], 5]
# ['42349037', '굽도 높고 샹각보다 푹신해서 신기 좋고 가성비 갑인 것 같아요', ['착용감', '디자인', '가성비'], 5]
# ['42282405', '너무너무 마음에 들어요', ['기타'], 5]
# ['42282405', '데일리로 무난히 좋습니다', ['기타'], 5]
# ['42265770', '신어봤는데 편안합니다', ['착용감'], 5]
# ['42265770', '굽도어느정도있어서 저는 만족합니다', ['디자인'], 5]
# ['42265738', '신어봤는데 편안합니다', ['착용감'], 5]
# ['42265738', '굽도어느정도있어서 저는 만족합니다', ['디자인'], 5]
# ['42196875', '키높이가 꽤 있어서 좋아요', ['디자인'], 4]
# ['42196875', '입문용으로 좋은거같아요', ['가성비'], 4]
# ['42196859', '키높이가 꽤 있어서 좋아요', ['디자인'], 4]
# ['42196859', '입문용으로 좋은거같아요', ['가성비'], 4]
# ['42072777', '한치수크게 신는게 좋으실거에요', ['사이즈'], 5]
# ['42072777', '딱맞게신으면 끼는느낌', ['착용감', '사이즈'], 5]
# ['41938489', 'n년차 이브랜드만 구매중인 사람이에요', ['기타'], 5]
# ['41938489', '6켤레 이상 산것같은데 밑창 내구도가 낮아서 1년정도 지속적으로 신으면 밑창이 상해서 계속 구매하게되는 대신 살면서 샀던 신발중 손에 꼽게 편해요', ['착용감'], 5]
# ['41938489', '운동화급', ['기타'], 5]
# ['41831187', '발도 편하고 정사이즈로 신으면 좋은것같아요', ['착용감', '사이즈'], 5]
# ['41816348', '가성비 더비슈즈 찾으시면 추천해요', ['가성비'], 5]
# ['41816348', '불편하진 않아요', ['착용감'], 5]
# ['41793976', '발도 편하고 색감도 괜찮아서 즐겨 신고 있습니다', ['착용감', '디자인'], 4]
# ['41746180', '오래 신어도 발이 안 아프고 편안해서 좋고요 키 높이 효과도 괜찮습니다 가성비 굿', ['착용감', '내구성 및 품질', '디자인', '가성비'], 5]
# ['41706292', '색감 이쁘고 핏도 제가 바라던 핏이에요', ['디자인'], 5]
# ['41706292', '강추드려요', ['기타'], 5]
# ['41706274', '색감 이쁘고 핏도 제가 바라던 핏이에요', ['디자인'], 5]
# ['41706274', '강추드려요', ['기타'], 5]
# ['41680959', '남친 사주려고 선물', ['기타'], 4]
# ['41680959', '만족해 합니다 이뻐용', ['디자인'], 4]
# ['41664291', '재질상 유광 느낌이 어색하지만 점차 사라지려나요', ['착용감', '내구성 및 품질', '디자인'], 4]
# ['41664291', '점잠 맘에 들길 바란답니다', ['기타'], 4]
# ['41663868', '빛에의해 유광 느낌이 개인적으로 어색합니다', ['착용감', '디자인'], 4]
# ['41662744', '이미 표면에서 유광 느낌이 원했던 모습이 아니네요', ['착용감'], 4]
# ['41662744', '점차 사라지겠죠', ['기타'], 4]
# ['41653573', '발이 크신분들은 사시면 놀랄수도 있다는점 주의하시구요 ', ['사이즈'], 5]
# ['41653573', '저는 정장에 신고 다니는데 나쁘진 않다', ['기타'], 5]
# ['41653573', '가성비다 라구 말할께요', ['가성비'], 5]
# ['41652121', '굽이 있고 키가 커보이네요', ['디자인'], 4]
# ['41652121', '행사용으로 잘신었어요', ['기타'], 4]
# ['41552721', '재구매인데 나쁘지 않아요', ['기타'], 5]
# ['41552721', '가성비도 좋고 출근용으로 쓰는즁이에여', ['가성비'], 5]
# ['41495682', '얇아서 막 고급진 느낌을 받을 수는 없지만 가격상의 이점이 있으니까 적당한 듯 싶네요', ['착용감', '디자인', '가성비'], 5]
# ['41448554', '이뻐요', ['디자인'], 5]
# ['41448554', '이뻐요', ['디자인'], 5]
# ['41448554', '이뻐요', ['디자인'], 5]
# ['41448554', '이뻐요', ['디자인'], 5]
# ['41409050', '색깔 사이즈 전부 마음에 드네요', ['사이즈', '디자인'], 5]
# ['41409050', '오랜만에 옷 사입네요', ['디자인'], 5]
# ['41350976', '데일리로 신으려고 구매했는데 만족합니다 이뻐요', ['디자인'], 5]
# ['41344151', '후기가 늦었는데 편하게 데일리로 잘 신고 있습니다', ['착용감'], 5]
# ['41290564', '군화 300 운동화 290 신던 사람입니다', ['사이즈'], 5]
# ['41290564', '사이즈에 대한 걱정을 많이했는데 맞네요', ['사이즈'], 5]
# ['41290564', '발볼은 있는 편입니다', ['사이즈'], 5]
# ['41290564', '참고하셔서 구매하시면 될거같습니다', ['기타'], 5]
# ['41275807', '입문용으로 신기 좋아요', ['가성비'], 5]
# ['41275807', '도전해보세요', ['기타'], 5]
# ['41275807', '대신 짧은양말신으면 뒷꿈치 아파요', ['착용감', '디자인'], 5]
# ['41274025', '기본템으로 더비슈즈 찾다가 가죽소재라 구매했습니다', ['내구성 및 품질'], 5]
# ['41274025', '착화감 괜찮네요', ['착용감'], 5]
# ['41274019', '기본템으로 더비슈즈 찾다가 가죽소재라 구매했습니다', ['내구성 및 품질'], 5]
# ['41274019', '착화감 괜찮네요', ['착용감'], 5]
# ['41274016', '기본템으로 더비슈즈 찾다가 가죽소재라 구매했습니다', ['내구성 및 품질'], 5]
# ['41274016', '착화감 괜찮네요', ['착용감'], 5]
# ['41246817', '발볼이 넓은 편인데 한치수 위로 사니까 잘맞고 가성비좋은 예쁜 신발입니다', ['사이즈', '디자인', '가성비'], 5]
# ['41244558', '가성비 좋은데 예쁜 신발 잘 고른거 같아요', ['디자인', '가성비'], 5]
# ['41224575', '입문용으로 샀습니다', ['가성비'], 5]
# ['41224575', '가격대비 좋은 착용감이고 270 정사이즈 발을 가져서 실패없이 구매했습니다', ['착용감', '사이즈', '가성비'], 5]
# ['41182260', '편하고 이뻐요', ['착용감', '디자인'], 5]
# ['41182260', '다음에 다 쓰면 재구매의사 있습니다', ['기타'], 5]
# ['41181301', '편하고 이뻐요', ['착용감', '디자인'], 5]
# ['41181301', '다음에 다 쓰면 재구매의사 있습니다', ['기타'], 5]
# ['41181287', '편하고 이뻐요', ['착용감', '디자인'], 5]
# ['41181287', '다음에 다 쓰면 재구매의사 있습니다', ['기타'], 5]
# ['41167843', '사이즈 딱맞고 예쁘네요', ['착용감', '사이즈', '디자인'], 5]
# ['41167843', '마감도 좋고 만족합니다', ['내구성 및 품질'], 5]
# ['41162883', '발이 편하고 착화감이 좋네요', ['착용감'], 5]
# ['41162883', '잘 신을게요', ['기타'], 5]
# ['41162883', '감사해요', ['기타'], 5]
# ['41147255', '다른 후기 평들처럼 가성비 좋고 전투화로 신기 좋아요', ['가성비'], 4]
# ['41139340', '구두와 운동화의 중간 정도의 편안함이고 발볼은 넓어요', ['착용감', '사이즈'], 5]
# ['41139274', '운동화와 구두 중간정도의 편안함이에요', ['착용감'], 5]
# ['41139274', '발볼은 넉넉해요', ['사이즈'], 5]
# ['41046972', '가성비 좋은 제품같아요', ['가성비'], 5]
# ['41046972', '라이트하게 신기 좋아요', ['기타'], 5]
# ['41014534', '가격대비 괜찮아요', ['가성비'], 5]
# ['41014534', '전체적으로 디자인이 마음에 들어요', ['디자인'], 5]
# ['40950639', '오래 신고 걸었는데도 발이 불편하지 않더라고요', ['착용감', '내구성 및 품질'], 5]
# ['40950639', '좋은거 같습니다', ['기타'], 5]
# ['40949888', '저번에 처음 구매했다가 이번에 재구매 해서 쓰고있어요 편합니다', ['기타'], 4]
# ['40917154', '사이즈도 딱맞고 쉐입이 예뻐요', ['착용감', '사이즈', '디자인'], 3]
# ['40917154', '잘 신을게요', ['기타'], 3]
# ['40881284', '가격에 비해 튼튼하고 착용감도 좋아요', ['착용감', '내구성 및 품질', '가성비'], 5]
# ['40881284', '낡으면 또 살 듯', ['기타'], 5]
# ['40881198', '가격에 비해 튼튼하고 착용감도 좋아요', ['착용감', '내구성 및 품질', '가성비'], 5]
# ['40881198', '낡으면 또 살 듯', ['기타'], 5]
# ['40806518', '가격에 비해 굉장히 편하고 보기에도 고급져요', ['착용감', '디자인', '가성비'], 5]
# ['40806518', '자주 신을것같아요', ['기타'], 5]
# ['40798727', '가격대비 좋아서 가성비로 신고다니면 딱인듯', ['착용감', '가성비'], 4]
# ['40798727', '합니다', ['기타'], 4]
# ['40770997', '사이즈 적당하고 다른 더비에 비해 착화감이 좋습니다', ['착용감', '사이즈'], 5]
# ['40758666', '초보자가 신기에 무난무난해여 그렇디않슺니까', ['기타'], 4]
# ['40730559', '신발 가볍고 착화감 좋아요', ['착용감'], 5]
# ['40730559', '큰데 꽉끈해서 신으면 괜찮아요', ['사이즈'], 5]
# ['40730553', '사이즈 큰데 꽉끈해서 신으면 괜찮아요', ['사이즈'], 5]
# ['40730553', '신발도 가볍고 착화감도 괜찮네요', ['착용감'], 5]
# ['40722767', '출근할때 신으려고샀는데 편하게 잘신고다녀요', ['착용감'], 5]
# ['40722767', '가성비 좋습니다', ['가성비'], 5]
# ['40716232', '이쁘기도하고 착용감도 편해서 자주 신을것같아요', ['착용감', '디자인'], 5]
# ['40715151', '신발 위쪽 가죽 본드칠 된 부분이 쌀짝 떨어질려 하는데 끈으로 꽉 조이니깐 문제는 없네요', ['사이즈', '내구성 및 품질'], 5]
# ['40715151', '가격 대비 퀄리티가 좋아요', ['내구성 및 품질', '가성비'], 5]
# ['40703841', '베이직한 더비슈즈 느낌 너무너무 편안해서 여행 내내 잘 신고 다녔습니당', ['착용감', '디자인'], 5]
# ['40666804', '제가 신으려고 산 건 아니지만 구두가 편하고 이쁘네요', ['착용감', '디자인'], 5]
# ['40666804', '가격도 저렴해서 좋습니다', ['가성비'], 5]
# ['40666738', '제가 신으려고 산 건 아니지만 구두가 편하고 이쁘네요', ['착용감', '디자인'], 5]
# ['40666738', '가격도 저렴해서 좋습니다', ['가성비'], 5]
# ['40666714', '제가 신으려고 산 건 아니지만 구두가 편하고 이쁘네요', ['착용감', '디자인'], 5]
# ['40666714', '가격도 저렴해서 좋습니다', ['가성비'], 5]
# ['40654267', '기본 더비 슈즈로 시작하기 좋은거 같네요', ['사이즈'], 4]
# ['40654267', '예쁩니다', ['디자인'], 4]
# ['40652329', '더비 처음 신어보는데 이뻐요', ['디자인'], 5]
# ['40652329', '친구 결혼식이 있어서 샀는데 편안하게 신고 갈 수 있을 것 같아요', ['착용감'], 5]
# ['40639159', '발이 편해서 좋아요', ['착용감'], 5]
# ['40639159', '앞으로 자주자주 신을 것 같아요', ['디자인'], 5]
# ['40638841', '처음 구두 사서 신어보는데 발이 편해서 좋은 것 같아요', ['착용감'], 5]
# ['40626189', '친구 생일선물로 샀는데 친구도 마음에 들어합니다', ['기타'], 5]
# ['40555484', '이런류의 신발을 처음 신어봤는데 가격대비 이쁘고 착화감도 편해요', ['착용감', '디자인', '가성비'], 5]
# ['40555257', '이런류의 신발을 처음 신어봤는데 가격대비 이쁘고 착화감도 편해요', ['착용감', '디자인', '가성비'], 5]
# ['40452843', '무난하게 신기 좋은 구두입니다', ['기타'], 5]
# ['40452843', '잘신고있습니다', ['기타'], 5]
# ['40449359', '계속 잘 신고 있습니다', ['기타'], 5]
# ['40449359', '감사합니다', ['기타'], 5]
# ['40449359', '잘 어울리네요', ['디자인'], 5]
# ['39597873', '가성비 구두로 추천드립니다', ['가성비'], 5]
# ['39597873', '착화감도 굉장히 편안해요', ['착용감'], 5]
# ['40441900', '말랑말랑하고 땀이 차는 재질인 것 같은데 가격 생각하면 퀄리티는 좋습니다', ['내구성 및 품질', '가성비'], 5]
# ['40402367', '구두같지 않고 푹신해서 좋아요', ['착용감'], 5]
# ['40402367', '디자인도 무난하고 입문용으로 좋아요', ['디자인', '가성비'], 5]
# ['40402321', '구두같지 않고 푹신해서 좋아요', ['착용감'], 5]
# ['40402321', '디자인도 무난하고 입문용으로 좋아요', ['디자인', '가성비'], 5]
# ['40390430', '가죽 소재가 얇습니다', ['내구성 및 품질'], 5]
# ['40390430', '편안하고 기본적인 느낌의 구두입니다', ['착용감'], 5]
# ['40389655', '가성비 굿 아이템잊니다', ['가성비'], 5]
# ['40389655', '활용도도 좋아서 두번째 구매해요', ['기타'], 5]
# ['40103500', '두번째 구매입니다', ['기타'], 5]
# ['40103500', '여전한 퀄리티네요', ['내구성 및 품질'], 5]
# ['40103500', '잘 신겠습니다', ['기타'], 5]
# ['40321101', '상품 받으셨을때 사이즈 잘 확인하세요', ['사이즈'], 3]
# ['40321101', '사이즈가 한사이즈 크게 배송되었네요', ['사이즈', '배송 및 포장 및 응대'], 3]
# ['40261358', '투박하지만 느낌내기 좋음', ['착용감'], 5]
# ['40261358', '키가 많이 커짐', ['기타'], 5]
# ['40261358', '안전화냐고 가끔 사람들이 물어봄', ['기타'], 5]
# ['40236850', '더비 슈즈 처음 입문했는데 편하고 안아파요', ['착용감', '가성비'], 5]
# ['40228718', '편합니다', ['기타'], 4]
# ['40228718', '색상은 반타블랙이 아닌듯 어쨌든 개추', ['디자인'], 4]
# ['40216855', '신어본 구두 종류중에선 폭신하고 편안한 것 같아요', ['착용감'], 5]
# ['40216855', '갠적으로 사이즈는 원래 신는대로 가면 맞는다고 느꼈습니당', ['사이즈'], 5]
# ['40216855', '광택도 과하지 않게 나는 정도라 만족합니다', ['디자인'], 5]
# ['40214132', '나이키 조던 280mm 에어포스 275mm에 발볼은 중간 정도인데 280mm사이즈 길이 남지만 편안하게 잘 맞네요', ['착용감', '사이즈'], 5]
# ['40214132', '디자인 만족하고 품질도 나쁘지 않은듯 하고 그저 가성비가 좋다는 느낌입니다', ['착용감', '내구성 및 품질', '디자인', '가성비'], 5]
# ['40208670', '너무가볍고 편합니다', ['착용감'], 5]
# ['40208670', '가성비 좋은듯 해요', ['가성비'], 5]
# ['40150762', '무난하게 더비슈즈 입문용으로 괜찮아요', ['가성비'], 5]
# ['40150762', '걸을때도 편해요', ['착용감'], 5]
# ['40148097', '가격도 착하며 착화감도 편하고 첫 더비로 신기 좋습니다', ['착용감', '가성비'], 5]
# ['40148069', '가격도 착하며 착화감도 편하고 첫 더비로 신기 좋습니다', ['착용감', '가성비'], 5]
# ['40133975', '한 거랑 같고 크기도 적당하고 심플 하니 좋아요', ['사이즈', '디자인'], 5]
# ['40133975', '가성비 최고', ['가성비'], 5]
# ['40121826', '사이즈가 마음에 드네요', ['사이즈'], 5]
# ['40121826', '가겨대비 굉장히 만족해요', ['기타'], 5]
# ['40117552', '이 가격에 이 정도 퀄리티와 착화감이면 만족합니다', ['착용감', '내구성 및 품질', '가성비'], 4]
# ['40116593', '착화감 편하고 입문용으로 신기 좋아용', ['착용감', '가성비'], 5]
# ['40116512', '착화감 엄청편하고 가격도 저렴해서 입문용으로 좋아용', ['착용감', '가성비'], 5]
# ['40116292', '착화감 편하고 가격도 저렴해서 입문하기 좋아용', ['착용감', '가성비'], 5]
# ['40074490', '오래 신어도 발이 안아파서 좋습니다', ['착용감', '내구성 및 품질'], 5]
# ['40074490', '이쁜건 기본이고요', ['디자인'], 5]
# ['39982335', '가죽상태 좋아서 정사이즈 추천드리고요', ['사이즈', '내구성 및 품질'], 5]
# ['39982335', '이쁘게', ['디자인'], 5]
# ['39982335', '잘만들어졌습니다', ['기타'], 5]
# ['39974978', '두번째 구매입니다', ['기타'], 5]
# ['39974978', '여전한 퀄리티네요', ['내구성 및 품질'], 5]
# ['39974978', '잘 신겠습니다', ['기타'], 5]
# ['39966775', '편하고 광택도 제가 원하는 정도인것 같아요', ['착용감', '디자인'], 4]
# ['39958400', '신어본 더비 중에 편하고 푹신푹신해서 좋아요', ['착용감'], 5]
# ['39954768', '신발 예뻐요', ['디자인'], 5]
# ['39954768', '차려입어야 할때 입고 가면 좋아요', ['기타'], 5]
# ['39945655', '가성비 좋고 착화감 운동화처럼 편안해서 좋아요', ['착용감', '가성비'], 5]
# ['39939604', '이쁘고 코디하기 쉬울꺼 같아서 좋아요', ['디자인'], 5]
# ['39930072', '편한건아니지만 예쁘게 신을수있을거같아요', ['착용감', '디자인'], 5]
# ['39930072', '', ['기타'], 5]
# ['39907536', '배송이 빨라서 좋구 실물이 더좋은데 생각보다사이즈가 커서 아쉬워용', ['사이즈', '디자인', '배송 및 포장 및 응대'], 5]
# ['39903811', '가성비 좋고요', ['가성비'], 4]
# ['39903811', '저는 나키 275 신는데 한 치수 작게 주문했는데 맞네요', ['사이즈'], 4]
# ['39903721', '4번 신어본 결과 가성비 좋아요', ['가성비'], 4]
# ['39903721', '발도 안아프고 좋네요', ['착용감'], 4]
# ['39891906', '핏이 이쁜 더비슈즈 착화감 예술입니다', ['착용감', '디자인'], 5]
# ['39891906', '편하고 키높이 효과까지', ['착용감', '디자인'], 5]
# ['39889104', '앞부분이 둥글해서 정사이즈보다 큰감이 있네요', ['사이즈', '디자인'], 4]
# ['39864999', '적당히 알바할 때 구두 필요해서 샀는데 편하고 굽이 놉지 않아서 아무렇게 신기에 좋아요 보기에도 이쁘니 편안함과 멋을 함께 챙길 수 있어용', ['착용감', '디자인'], 5]
# ['39863736', '착화감 별 기대 안 했는데 편하네요', ['착용감'], 5]
# ['39863736', '디자인도 깔끔해서 좋아요', ['디자인'], 5]
# ['39860247', '어느 정도 굽이 있는데도 착용감 편하고 좋습니다', ['착용감', '디자인'], 5]
# ['39856125', '굿이에용', ['기타'], 4]
# ['39856125', '딱좋기는한데 많이걸어다닐거면 힘들어용', ['착용감'], 4]
# ['39843614', '인생신발입니다', ['기타'], 5]
# ['39843614', '출퇴근할때 맨날 신어요', ['기타'], 5]
# ['39843614', '내구성도 굿', ['내구성 및 품질'], 5]
# ['39809979', '데일리 슈즈로 딱입니다', ['착용감'], 5]
# ['39809979', '가격도 저렴하게 사서 좋네요', ['가성비'], 5]
# ['39809979', '굽이 딱딱하지 않아서 좋아요', ['착용감', '디자인'], 5]
# ['39796519', '상품 좋아요', ['기타'], 4]
# ['39796519', '키높이도 되고 캐쥬얼이나 정장 어디에도 어울려요', ['디자인'], 4]
# ['39796519', '신발 끈이 일반 운동화 끈이 와서 아쉬워요', ['기타'], 4]
# ['39762559', '사이즈가 크게나와서 발이 아프지 않아요', ['착용감', '사이즈'], 5]
# ['39762559', '정사이즈 추천드립니다', ['사이즈'], 5]
# ['39743045', '가성비 좋음 오래 신을 수 있을 것 같진 않음', ['내구성 및 품질', '가성비'], 4]
# ['39743045', '깔창에서 오는 쿠션감', ['착용감'], 4]
# ['39741767', '가격이 마틴 13값이라 가성비는 훌륭한데 아무래도 어쨋든 구두이다보니 퀄리티 기준이 높게 되네요', ['내구성 및 품질', '가성비'], 4]
# ['39741767', '가죽 질감이 좋아보이진 않는데 질이 들어봐야 알 것 같고 바닥 마크는', ['사이즈', '내구성 및 품질'], 4]
# ['39741767', '비브람 느낌으로 노란색을 썼는지 모르겠는데 좌우 방향이 같은 개체가 있을까 싶네요', ['착용감', '디자인'], 4]
# ['39741767', '사이즈는 5미리라 반업반다운 고민하다 반다운했는데 꽉끼게 맞음', ['사이즈'], 4]
# ['39728773', '사이즈가 10단위라 큰거 같긴한데 편하게 신을게용 이쁩니다', ['착용감', '사이즈', '디자인'], 5]
# ['39701604', '신발 가격대비 괜찮아요', ['가성비'], 5]
# ['39701604', '하루 신어봣는데 대만족', ['기타'], 5]
# ['39696999', '저렴한 가격에 잘 샀습니다', ['가성비'], 5]
# ['39696999', '신발이 편해서 신기에 거부감이 없어서 좋아요', ['착용감'], 5]
# ['39696999', '잘 신고 다니고 있습니다', ['기타'], 5]
# ['39660605', '굽이 높네요', ['디자인'], 5]
# ['39660605', '가격대비 신을만합니다', ['가성비'], 5]
# ['39660603', '굽이 높네요', ['디자인'], 5]
# ['39660603', '가격대비 신을만합니다', ['가성비'], 5]
# ['39660592', '굽이 높네요', ['디자인'], 5]
# ['39660592', '가격대비 신을만합니다', ['가성비'], 5]
# ['39642135', '처음 구두 입문인데 싸고 좋아요', ['가성비'], 3]
# ['39642135', '딱딱하지만 데일리로 좋은 것 같습니다', ['착용감'], 3]
# ['39616944', '무난한 워커 입니다', ['기타'], 4]
# ['39616944', '여러모로 잘 신겠네요', ['기타'], 4]
# ['39616944', '사이즈도 맞고 색상도 잘나왔습니다', ['사이즈', '디자인'], 4]
# ['39613198', '휘뚜루 마뚜루 신기 좋습니다', ['기타'], 5]
# ['39613198', '이정도 가격에 딱좋게 신을수있습니다', ['착용감', '가성비'], 5]
# ['39597676', '굽 높아서 좋고 착화감 편안해서 좋습니다', ['착용감', '디자인'], 5]
# ['39597676', '구두치곤 굉장히 편한 축에 속하는 것 같아요', ['착용감'], 5]
# ['39597487', '튼튼하고편해요', ['착용감', '내구성 및 품질'], 5]
# ['39597487', '몇달째 신고 있는데도 흠집도 없고 길도잘들여지네요', ['기타'], 5]
# ['39596498', '빠르게 배송 받았고 착화감이 적당히 폭신하면서 좋네요', ['착용감', '배송 및 포장 및 응대'], 5]
# ['39596498', '외출은 아직 안해봤지만 좋습니다', ['기타'], 5]
# ['39583977', '발볼이 넓어서 항상 한사이즈업 해서 신는데 정사이즈로 신어도 편안하네요', ['착용감', '사이즈'], 5]
# ['39583936', '발볼이 넓어서 항상 한사이즈업 해서 신는데 정사이즈로 신어도 편안하네요', ['착용감', '사이즈'], 5]
# ['39583840', '발볼이 큰편이여서 항상 사이즈업해서 신는데 정사이즈로 신어도 편안하네요', ['착용감', '사이즈'], 5]
# ['39581535', '구두 처음 구매해봤는데 가격대도 적당하고 입문템으로 딱이에요', ['착용감', '가성비'], 5]
# ['39581329', '구두 처음 구매해봤는데 가격대도 적당하고 입문템으로 딱이에요', ['착용감', '가성비'], 5]
# ['39550808', '가성비 최고네요', ['가성비'], 5]
# ['39550808', '신발도 이쁘고 나중에 재구매 할거같네요', ['디자인'], 5]
# ['39524586', '주변 지인 추천으로 샀는데 가격대비 가성비 확실히 좋습니다', ['가성비'], 5]
# ['39510414', '발이 편해요', ['착용감'], 5]
# ['39510414', '좋습니다 ', ['기타'], 5]
# ['39510414', '디자인도 이쁘고자주신을꺼같아요', ['디자인'], 5]
# ['39510386', '발이 편해요', ['착용감'], 5]
# ['39510386', '좋습니다 ', ['기타'], 5]
# ['39510386', '디자인도 이쁘고자주신을꺼같아요', ['디자인'], 5]
# ['39503454', '편안하고 이뻐요', ['착용감', '디자인'], 5]
# ['39503454', '데일리로 활용잘할거같아요', ['기타'], 5]
# ['39503454', '무슨바지든 잘어울려요', ['디자인'], 5]
# ['39503446', '편안하고 이뻐요', ['착용감', '디자인'], 5]
# ['39503446', '데일리로 활용잘할거같아요', ['기타'], 5]
# ['39503446', '무슨바지든 잘어울려요', ['디자인'], 5]
# ['39503427', '편안하고 이뻐요', ['착용감', '디자인'], 5]
# ['39503427', '데일리로 활용잘할거같아요', ['기타'], 5]
# ['39503427', '무슨바지든 잘어울려요', ['디자인'], 5]
# ['39451718', '좋습니다', ['기타'], 5]
# ['39451718', '원하는 핏이에요', ['디자인'], 5]
# ['39451718', '이쁘게 입겠습니다', ['디자인'], 5]
# ['39434598', '키가 커지는느낌 발뒤꿈치가 아프네요', ['착용감', '디자인'], 5]
# ['39434598', '가격대비 가성비 아이템', ['가성비'], 5]
# ['39379535', '신발 265270신는데 270하니까 여유 있게 신을 수 있네요', ['사이즈'], 5]
# ['39379535', '부츠는 10업해서 신는 편인데', ['사이즈'], 5]
# ['39379438', '디자인 이쁘게 잘 빠졌고 착화감 나쁘지 않아요', ['착용감', '디자인'], 5]
# ['39338640', '편하고 잘 애용하겠습니다', ['착용감'], 4]
# ['39338640', '감사합니다', ['기타'], 4]
# ['39338640', '잘 신을게용', ['기타'], 4]
# ['39321469', '입문용 더비로 하나 구입하는거면 추천드립니다', ['가성비'], 5]
# ['39293440', '라이즈도 좋고 편해요', ['착용감'], 5]
# ['39293440', '잘 샀습니다', ['기타'], 5]
# ['39293440', '재구매도 의사 있아요', ['기타'], 5]
# ['39267272', '가성비로 최고네요', ['가성비'], 4]
# ['39267272', '데일로 편하게 신고있습니다', ['착용감'], 4]
# ['39267272', '많이 파세요', ['기타'], 4]
# ['39222865', '가성비 좋은 더비슈즈네요', ['가성비'], 4]
# ['39222865', '굽도 있는 편이고 착화감 편해서 좋아요', ['착용감', '디자인'], 4]
# ['39095204', '발볼이 넓은편이라 한치수 업했는데 정사이즈로 사셔도 괜찮을 것 같아요', ['사이즈'], 5]
# ['39095204', '가격대비 좋은 더비슈즈입니다', ['가성비'], 5]
# ['39074859', '전투용으로 좋은것 같습니다', ['기타'], 4]
# ['39074859', '단지 발등이 높은 분들은 불편할거같아요', ['착용감', '사이즈'], 4]
# ['39074859', '발등이 아픈데 신습니다', ['착용감', '사이즈'], 4]
# ['39060871', '불편하지도 않고 착용감이 좋아서 오래신어도 괜찮을꺼 같아요', ['착용감', '내구성 및 품질'], 5]
# ['39055811', '가격정도 합니다', ['가성비'], 4]
# ['39055811', '이 가격에 간단히 신을 구두라면 만족합니다', ['가성비'], 4]
# ['38970745', '발이 편해서 자주 손이 갈 거 같습니다', ['착용감'], 5]
# ['38970745', '구두가 필요한 날에 제 역할을 해줄만한 아이템입니다', ['기타'], 5]
# ['38970419', '착화감이 거의 운동화만큼 편한거 같아요', ['착용감'], 5]
# ['38970419', '사이즈도 정사이즈로 보시면 될 거 같구요', ['사이즈'], 5]
# ['38970419', '구두가 필요한 날에 편하게 신기 좋을거 같습니다', ['착용감'], 5]
# ['38956907', '세일할때 구매해서 저렴하게 가성비있게 잘 구매한듯 하네요', ['가성비'], 5]
# ['38934269', '청바지에 입기에도 잘 어울리고 좋네요', ['디자인'], 5]
# ['38934269', '추천드립니다', ['기타'], 5]
# ['38921934', '저렴한 가격에 잘 사서 자주 신고 다니는데 예뻐서 맘에 들어요', ['디자인', '가성비'], 5]
# ['38920581', '원래 280신는데 그대로 사니까 적당합니다', ['사이즈'], 5]
# ['38920581', '좋아요', ['기타'], 5]
# ['38879984', '가성비 짱입니다', ['가성비'], 5]
# ['38879984', '발도 편하고 잘 신고있어 좋습니다', ['착용감'], 5]
# ['38877543', '잘 받았어요', ['기타'], 4]
# ['38877543', '마감처리가 참 아쉽지만 나쁘진 않아요', ['내구성 및 품질'], 4]
# ['38877536', '잘 받았어요', ['기타'], 4]
# ['38877536', '마감처리가 참 아쉽지만 나쁘진 않아요', ['내구성 및 품질'], 4]
# ['38861264', '더비슈즈를 저렴하게 입문할 수 있어서 좋았던 것 같습니다', ['가성비'], 5]
# ['38861264', '디자인도 무난해서 포멀한 자리에 갈 때 신기 좋습니다', ['디자인'], 5]
# ['38810372', '가볍게 신기 좋은거같아요', ['착용감'], 5]
# ['38810372', '가격도싸고 마음에드네요', ['가성비'], 5]
# ['38799319', '출근용으로 자주 신습니다', ['기타'], 5]
# ['38799319', '착화감 좋아요', ['착용감'], 5]
# ['38799319', '편하네요', ['착용감'], 5]
# ['38758468', '장시간 착용하고 걸어다녀도 발 아프지 않고 쿠션감이 좋아요', ['착용감'], 5]
# ['38756811', '여기저기 스타일링하기 좋아요', ['디자인'], 5]
# ['38756811', '가성비 좋습니다', ['가성비'], 5]
# ['38756147', '원래 255신는데 250사니까 맞았어요', ['사이즈'], 5]
# ['38754835', '한번 신어봤는데 괜찮아요', ['기타'], 5]
# ['38754835', '무난합니다', ['기타'], 5]
# ['38754835', '이십자자', ['기타'], 5]
# ['38750637', '더비 입문으로 좋은 것 같습니다', ['가성비'], 5]
# ['38750637', '착화감도 굉장히 편안하네요', ['착용감'], 5]
# ['38749934', '더비 입문으로 좋은 것 같습니다', ['가성비'], 5]
# ['38749934', '착화감도 굉장히 편안하네요', ['착용감'], 5]
# ['38727438', '사이즈 앞뒤길이가 크긴한데 일부러 크게만든건지 커서 걸을때 타제품보다 훨신 편해요', ['착용감', '사이즈', '디자인'], 5]
# ['38725920', '사이즈 굿 착화감 굿 발도안아프고아주만족스럽', ['착용감', '사이즈'], 5]
# ['38696610', '모양은 무난만 기본 구두입니다', ['디자인'], 5]
# ['38696610', '무엇보다 가격대비 가성비가 좋습니다', ['가성비'], 5]
# ['38696610', '고급스러워요', ['디자인'], 5]
# ['38671523', '발볼이랑 발등 높은편인데 하나도 안불편하고 잘 신고있습니다', ['착용감', '사이즈'], 5]
# ['38671523', '평소 신발은 265신는데 260신어도 괜찮네요', ['사이즈'], 5]
# ['38583498', '기본 블랙 더비슈즈로 추천합니다', ['디자인'], 5]
# ['38583498', '입문용으로 부담없고 좋아요', ['가성비'], 5]
# ['38583498', '', ['기타'], 5]
# ['38575423', '생각한거보다 사이즈가 많이 커요', ['사이즈'], 5]
# ['38575423', '정사이즈에서 한사이즈 줄이시는게 나을거 같아용', ['사이즈'], 5]
# ['38573842', '구두 특성상 딱딱한건 있는듯요', ['착용감'], 5]
# ['38573842', '발볼이 좁아서 크게 시켰는데 괜찮아요', ['착용감', '사이즈'], 5]
# ['38573842', '대신 뒷꿈치는 어쩔수없이 까지는듯요', ['착용감', '디자인'], 5]
# ['38530943', '괜찮은것같아요', ['기타'], 5]
# ['38530943', '사이즈도 맞고 편합니다', ['사이즈'], 5]
# ['38530943', '추천', ['기타'], 5]
# ['38507158', '외출용으로 신을만한 신발이 없어서 구매했는데 부담스럽지도 않고 데일리하게 신기 좋아요', ['기타'], 5]
# ['38486253', '구두를 처음 사봤는데 입문용으로 좋은거같아요', ['가성비'], 5]
# ['38486253', '데일리로 신기에도 부답스럽지 않고 좋아요', ['기타'], 5]
# ['38408449', '사이즈는 하나 작은게 좋은 것 같아요', ['사이즈'], 5]
# ['38408449', '깔끔하고 예쁩니다', ['디자인'], 5]
# ['38380043', '이런저런 다괜찮은데 발바닥이 불편하긴함', ['착용감'], 4]
# ['38380043', '아쉬움', ['기타'], 4]
# ['38373868', '신발 깔끔하고 가성비 좋네요', ['가성비'], 5]
# ['38373868', '굽이 높아서 놀랐어요', ['디자인'], 5]
# ['38373850', '신발 이쁘네요', ['디자인'], 5]
# ['38373850', '편하고 굽이 높아서 키가 커져서 좋아요', ['착용감', '디자인'], 5]
# ['38371522', '사이즈 적당하고 발도 편안하니 좋습니다', ['착용감', '사이즈'], 5]
# ['38371522', '추천합니다', ['기타'], 5]
# ['38339238', '신발너무편합니다', ['기타'], 5]
# ['38339238', '자꾸왼쪽 발이 신발끈이풀리는데 그것만빼면 너무편합니다', ['기타'], 5]
# ['38339238', '새제품인데도 전혀안아픕니다', ['기타'], 5]
# ['38334492', '키높이도 있고 나름 디자인도 깔끔해서 가성비 제품입니다', ['디자인', '가성비'], 4]
# ['38301725', '더비 치고 착화감도 괜찮고 좋네요', ['착용감'], 5]
# ['38301725', '사이즈는 크게 나온 거 같아요', ['사이즈'], 5]
# ['38301725', '정사이즈 구매하시면 널널하게 신을 수 있어요', ['사이즈'], 5]
# ['38290415', '이정도 가격에 퀄리티가 미쳤어요', ['내구성 및 품질', '가성비'], 5]
# ['38290415', '확실히 착화감이 좋아요', ['착용감'], 5]
# ['38246158', '동글동글 입기 좋아요', ['기타'], 5]
# ['38246158', '캐주얼이나 포멀이나 둘 다 매치 가능해요', ['디자인'], 5]
# ['38209491', '편안 무난 가격도 합리적 더비 없으시면 후회는 안할듯', ['착용감', '가성비'], 5]
# ['38205924', '다좋은데 입문용으로 오래걸을시 발이조금아파요', ['착용감', '내구성 및 품질', '가성비'], 4]
# ['38205913', '괜찮은데 입문용으로 발이 아픔 오래걸을시', ['착용감', '내구성 및 품질', '가성비'], 4]
# ['38204733', '더비슈즈 입문용으로 샀는데 맘에듭니다', ['가성비'], 5]
# ['38204733', '착화감이좋아요', ['착용감'], 5]
# ['38203524', '더비슈즈 처음 구매해보는데 가성비 좋게 잘 산 것 같습니다', ['가성비'], 5]
# ['38202102', '보통 처음신으면 뒤꿈치 아픈데 그런게 없는거같아요', ['착용감', '디자인'], 5]
# ['38202102', '부드러우면서 빳빳하게 신발 잘 만드신듯 ', ['착용감'], 5]
# ['38190095', '더비슈즈 처음 구매해보는데 가성비 좋게 잘 산 것 같습니다', ['가성비'], 5]
# ['38190028', '더비슈즈 처음 구매해보는데 가성비 좋게 잘 산 것 같습니다', ['가성비'], 5]
# ['38147869', '친척 결혼식때문에 급하게 구입했는데 괜찮네요', ['기타'], 5]
# ['38147869', '가상비 굿굿', ['기타'], 5]
# ['38131869', '지인 결혼식때문에 급하게 구매했는데 편해요', ['착용감'], 5]
# ['38131869', '가성비 굿', ['가성비'], 5]
# ['38119352', '유광이 아니라 무난하고 착화감 좋고 키높이 기능이 있어서 좋습니다', ['착용감', '디자인'], 5]
# ['38119039', '고급스러워보이고 착화감이 좋아요', ['착용감', '디자인'], 5]
# ['38119039', '키높이 기능이 있어요', ['디자인'], 5]
# ['38077516', '색감 잘 나오고 사이즈도 맞아서 전투용으로 신기 좋아요', ['사이즈', '디자인'], 5]
# ['38077404', '사이즈는 운동화와 동일하고 예뻐서 입문용으로 좋아요', ['사이즈', '디자인', '가성비'], 5]
# ['38065795', '기대 이상으로 착화감이 좋습니다', ['착용감'], 5]
# ['38065795', '첫날 신었을 때부터 부드러운 느낌이 들어 좋아요', ['착용감'], 5]
# ['38063580', '굿굿따리 고급져', ['디자인'], 5]
# ['38063580', '', ['기타'], 5]
# ['38063580', '코디', ['디자인'], 5]
# ['38063580', '하기도 좋음', ['기타'], 5]
# ['38063545', '신발 예쁘고 고급스러워요', ['디자인'], 5]
# ['38063545', '코디하기도 좋고 굿', ['디자인'], 5]
# ['38052731', '무난하게 신기조아요 가성비좋습니다', ['가성비'], 5]
# ['38052731', '또 만나요', ['기타'], 5]
# ['38048109', '굽이 있는 편이여서 그런지 기존 신발들 보다는 작은 감이 있긴 한데 가죽 질 들이고 하면 괜찮을 것 같아요', ['사이즈', '내구성 및 품질', '디자인'], 4]
# ['38027993', '면접 경조사용으로 구매했는데 가격대비 퀄리티도 좋고 착화감도 마음에 듭니다', ['착용감', '내구성 및 품질', '가성비'], 5]
# ['38023853', '발볼이 적당하고 사이즈도 정사이즈 입니다', ['사이즈'], 5]
# ['38023853', '만족합니다', ['기타'], 5]
# ['38023810', '발볼도 적당하고 스타일이 좋습니다', ['사이즈', '디자인'], 5]
# ['38023810', '만족합니다', ['기타'], 5]
# ['38001621', '면접 경조사용으로 구매했는데 가격대비 퀄리티도 좋고 착화감도 마음에 듭니다', ['착용감', '내구성 및 품질', '가성비'], 5]
# ['37985365', '좋았어요', ['기타'], 5]
# ['37985365', '가성비 느낌으로 좋아요', ['착용감', '가성비'], 5]
# ['37985365', '회사에서도 신고 일상에서도 신기 좋아요', ['기타'], 5]
# ['37969160', '첼시 부츠 이후 첫 더비 부츠인데 발끝이 뾰족해서 이쁘네요', ['디자인'], 5]
# ['37969160', '기장 긴 바지랑 같이 코디하면 이쁠 것 같습니다', ['디자인'], 5]
# ['37969097', '발끝이 둥글한 것보다 역시 뾰족한 구두가 더 예쁜거 같아요', ['디자인'], 5]
# ['37966145', '가격대비 좋아요', ['가성비'], 5]
# ['37966145', '색감도 적당 편안함도 적당 정사이즈 갔습니다', ['착용감', '사이즈', '디자인'], 5]
# ['37958187', '원래 신발 265신는데 270은 오버 사이즈 느낌이네용 오버로 갈려면 5 맞을려면 5 고고', ['착용감', '사이즈'], 5]
# ['37958136', '구두인데 구두 같지 않을 정도로 편하고 좋습니당', ['착용감'], 5]
# ['37947151', '구두 입문용으로 사봤는데 좋아요', ['가성비'], 5]
# ['37947151', '착용감도 좋고 발볼도 넓어요', ['착용감', '사이즈'], 5]
# ['37947151', '오래신으면 뒷꿈치가 아프긴한데 추천합니다', ['착용감', '내구성 및 품질', '디자인'], 5]
# ['37935261', '운동화 신는 것처럼 편해요', ['착용감'], 5]
# ['37935261', '입문용으로 추천합니다', ['가성비'], 5]
# ['37931365', '사이즈 적당하고 발도 편안하니 좋습니다', ['착용감', '사이즈'], 5]
# ['37931365', '추천합니다', ['기타'], 5]
# ['37927493', '착화감 별 기대 안 했는데 편하네요', ['착용감'], 5]
# ['37927493', '디자인도 깔끔해서 좋아요', ['디자인'], 5]

# %% [markdown]
# # 테스트

# %%
import torch
from transformers import AutoTokenizer, BertForSequenceClassification

# 모델 및 토크나이저 로드
MODEL_PATH = "C:\최종프로젝트\kobert_sentiment_model(25.2.19).pth"
tokenizer = AutoTokenizer.from_pretrained("monologg/kobert")
model = BertForSequenceClassification.from_pretrained("monologg/kobert", num_labels=2)

# 저장된 모델 가중치 불러오기
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model.to(device)
model.eval()

# 감정 분석 함수
def predict_sentiment(sentence):
    encoding = tokenizer(
        sentence,
        padding="max_length",
        truncation=True,
        max_length=128,
        return_tensors="pt"  # 여기에 .to(device) 적용 X
    )

    # Tensor 데이터를 device로 이동
    input_ids = encoding["input_ids"].to(device)
    attention_mask = encoding["attention_mask"].to(device)

    with torch.no_grad():
        output = model(input_ids=input_ids, attention_mask=attention_mask)
        probs = torch.nn.functional.softmax(output.logits, dim=-1)
        label = torch.argmax(probs, dim=-1).item()

    sentiment = "긍정 😀" if label == 1 else "부정 😞"
    confidence = probs[0][label].item() * 100

    print(f"📝 입력 문장: {sentence}")
    print(f"📊 예측 결과: {sentiment} (확률: {confidence:.2f}%)")

    return label, confidence
# Out:
# The repository for monologg/kobert contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/monologg/kobert.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at monologg/kobert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-8-73f268bdf301>:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-73f268bdf301> in <cell line: 0>()
#       9 # 저장된 모델 가중치 불러오기
#      10 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ---> 11 model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
#      12 model.to(device)
#      13 model.eval()
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1317         pickle_load_args["encoding"] = "utf-8"
#    1318
# -> 1319     with _open_file_like(f, "rb") as opened_file:
#    1320         if _is_zipfile(opened_file):
#    1321             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     657 def _open_file_like(name_or_buffer, mode):
#     658     if _is_path(name_or_buffer):
# --> 659         return _open_file(name_or_buffer, mode)
#     660     else:
#     661         if "w" in mode:
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     638 class _open_file(_opener):
#     639     def __init__(self, name, mode):
# --> 640         super().__init__(open(name, mode))
#     641
#     642     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\최종프로젝트\\kobert_sentiment_model(25.2.19).pth'

# %%
import os

MODEL_PATH = "C:\\최종프로젝트\\kobert_sentiment_model(25.2.19).pth"

if os.path.exists(MODEL_PATH):
    print("✅ 파일이 존재합니다.")
else:
    print("❌ 파일이 존재하지 않습니다. 경로를 확인하세요.")
# Out:
# ❌ 파일이 존재하지 않습니다. 경로를 확인하세요.

# %%
# 🔥 Focal Loss 함수 추가
class FocalLoss(torch.nn.Module):
    def __init__(self, gamma=2.0):
        super(FocalLoss, self).__init__()
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = ((1 - pt) ** self.gamma * ce_loss).mean()
        return focal_loss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-421c03cc1151> in <cell line: 0>()
#       1 # 🔥 Focal Loss 함수 추가
# ----> 2 class FocalLoss(torch.nn.Module):
#       3     def __init__(self, gamma=2.0):
#       4         super(FocalLoss, self).__init__()
#       5         self.gamma = gamma
#
# NameError: name 'torch' is not defined
